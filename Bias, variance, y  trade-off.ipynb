# %% [markdown]
# <center><img src="imagen/variance.jpg" width="950" height="50"></center>

# %% [markdown]
# # **Autor: Naren Castellon**
# # **Bias, variance, y el trade-off**
# Machine learning los modelos no son perfectos; son propensos a una serie de errores. Las dos fuentes más comunes de errores son el sesgo y la varianza. Aunque son dos problemas distintos, están interconectados y se relacionan con el grado de libertad o complejidad disponible de un modelo.
#
# **Qué es el bias?**
#
# Bias o Sesgo se refiere a la incapacidad de un método para estimar correctamente el objetivo. Esto no solo se aplica al aprendizaje automático. Por ejemplo, en estadística, si queremos medir el promedio de una población y no muestreamos con cuidado, el promedio estimado estará sesgado. En términos simples, la estimación del método (muestreo) no coincidirá con el objetivo real (promedio).
# En el aprendizaje automático, el sesgo se refiere a la diferencia entre la predicción esperada y su objetivo. Los modelos sesgados no pueden ajustarse correctamente a los datos de entrenamiento, lo que da como resultado un rendimiento deficiente dentro y fuera de la muestra. Un buen ejemplo de modelo sesgado surge cuando intentamos ajustar una función seno con una regresión lineal simple. El modelo no puede ajustarse a la función seno, ya que carece de la complejidad necesaria para hacerlo. Por lo tanto, no podrá funcionar bien dentro o fuera de la muestra. Este problema se llama desajuste. Un ejemplo gráfico se ilustra en la siguiente figura:

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(123456)

def f(x):
    return np.sin(x)

def sample(size):
    max_v = 20
    step = size/max_v
    x = [x/step for x in range(size)]
    y = [f(x)+np.random.uniform(-0.25,0.25) for x in x]
    return np.array(x).reshape(-1,1), np.array(y).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
x, y = sample(100)


lr = LinearRegression()
lr.fit(x, y)
preds  =  lr.predict(x)
plt.figure(figsize=(10,5))
plt.scatter(x, y, label='data')
plt.plot(x, preds, color='orange', label='model')
plt.title('Modelo Bias')
plt.legend();

# %% [markdown]
# La fórmula matemática del sesgo es la diferencia entre el valor objetivo y la predicción esperada:
# $$Bias-E[y]-t$$

# %% [markdown]
# ## **¿Qué es la varianza?**
# La varianza se refiere a cuánto varían los individuos dentro de un grupo. Una vez más, la varianza es un concepto de las estadísticas. Tomando una muestra de una población, la varianza indica cuánto difiere el valor de cada individuo de la media.
#
# En el **Machine Learning**, la varianza se refiere a la variabilidad o sensibilidad del modelo a los cambios en los datos. Esto significa que los modelos de alta varianza generalmente pueden ajustarse bien a los datos de entrenamiento y, por lo tanto, lograr un alto rendimiento dentro de la muestra, pero tienen un rendimiento deficiente fuera de la muestra. Esto se debe a la complejidad del modelo. Por ejemplo, un árbol de decisiones puede tener una gran variación si crea una regla
# para cada instancia del conjunto de datos de entrenamiento. A esto se le llama sobreajuste. La siguiente figura muestra un árbol de decisiones entrenado en el conjunto de datos anterior. Los puntos azules representan los datos de entrenamiento y los puntos naranjas representan los datos de la prueba.
#
# Como es evidente, el modelo se ajusta perfectamente a los datos de entrenamiento, pero no funciona tan bien en los datos de prueba:

# %%
from sklearn.tree import DecisionTreeRegressor
x, y = sample(100)

dt = DecisionTreeRegressor()
dt.fit(x, y)
plt.figure(figsize=(10,5))
plt.scatter(x, y, label='training data')
x, y = sample(100)
preds  =  dt.predict(x)
plt.plot(x, preds, color='black', label='model')
plt.scatter(x, y, label='test data')
plt.title('Modelo de alta varianza')
plt.legend();

# %% [markdown]
# La fórmula matemática para la varianza se representa de la siguiente manera:
#
# $$Variance=E[(y-E[y])^2] $$
#
# Esencialmente, esta es la fórmula estándar para la varianza de la población, asumiendo que nuestra población está compuesta por nuestros modelos, ya que han sido producidos por el algoritmo de aprendizaje automático. Por ejemplo, como vimos anteriormente, Actualización del aprendizaje automático, las redes neuronales pueden tener diferentes resultados de entrenamiento, dependiendo de sus pesos iniciales. Si consideramos todas las redes neuronales con la misma arquitectura, pero diferentes pesos iniciales, al entrenarlas, tendremos una población de diferentes modelos.

# %% [markdown]
# ## **Trade-off**
# Bias y variance son dos de los tres componentes principales que comprenden el error de un modelo. El tercero se denomina error irreductible y se puede atribuir a la aleatoriedad inherente o la variabilidad de los datos. El error total de un modelo se puede descomponer de la siguiente manera:
#
# $$Error=Bias^2 +variance+Irreducible error$$
#
# Como vimos anteriormente, el sesgo y la varianza provienen de la misma fuente: la complejidad del modelo. Si bien el sesgo surge de muy poca complejidad y libertad, la varianza prospera en modelos complejos. Por lo tanto, no es posible reducir el sesgo sin aumentar la varianza y viceversa. Sin embargo, existe un punto óptimo de complejidad, donde el error se minimiza ya que el sesgo y la varianza se encuentran en un punto óptimo de compensación. Cuando la complejidad del modelo está en este punto óptimo (la línea punteada roja en la siguiente figura), entonces el modelo funciona mejor tanto dentro como fuera de la muestra. Como es evidente en la siguiente figura, el error nunca se puede reducir a cero.

# %% [markdown]
# Además, aunque algunos pueden pensar que es mejor reducir el sesgo, incluso a costa de una mayor varianza, está claro que el modelo no funcionaría mejor, incluso si fuera insesgado, debido al error que inevitablemente induce la varianza:

# %%
def bias(complexity):
    return 100/complexity

def variance(complexity):
    return np.exp(complexity/28)

r = range(5, 100)

variance_ = np.array([variance(x) for x in r])
bias_ =  np.array([bias(x) for x in r])
sum_ = variance_ + bias_
mins = np.argmin(sum_)
min_line = [mins for x in range(0, int(max(sum_)))]


plt.figure(figsize=(12,5))
plt.plot(bias_, label=r'$bias^2$', linestyle='-')
plt.plot(variance_, label='variance', linestyle=':')
plt.plot(sum_, label='error', linestyle='-.')
plt.plot(min_line, [x for x in range(0, int(max(sum_)))], linestyle='--')
plt.title('Minimizar el error')
plt.legend()

# %% [markdown]
# La siguiente gráfico muestra el modelo perfecto, con una cantidad mínima de sesgo y varianza combinados, o error reducible. Aunque el modelo no se ajusta perfectamente a los datos, esto se debe al ruido inherente al conjunto de datos. Si intentamos ajustar mejor los datos de entrenamiento, induceremos un sobreajuste (varianza). Si intentamos simplificar aún más el modelo, induciremos
# desajuste (sesgo):

# %%
from sklearn.tree import DecisionTreeRegressor
x, y = sample(100)

plt.figure(figsize=(12,5))
plt.scatter(x, y, label='training data')

preds  =  f(x)
plt.plot(x, preds, color='orange', label='model')
plt.title('Modelo Perfecto');
plt.legend();

# %% [markdown]
# ## Bias, Variance para Regresión
# El siguiente ejemplo carga el conjunto de datos de viviendas de Boston directamente a través de la URL, lo divide en conjuntos de entrenamiento y prueba, luego estima el error cuadrático medio (MSE) para una regresión lineal, así como el sesgo y la varianza del error del modelo en 200 muestras de bootstrap.

# %%
# estimador del bias y variance para un modelo de regresión lineal
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from mlxtend.evaluate import bias_variance_decomp
# load dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/housing.csv'
dataframe = pd.read_csv(url, header=None)
# separate into inputs and outputs
data = dataframe.values
X, y = data[:, :-1], data[:, -1]
# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# definimos el modelo 
model_lr = LinearRegression()
# estimate bias and variance
mse, bias, var = bias_variance_decomp(model_lr, X_train, y_train, X_test, y_test, loss='mse', num_rounds=200, random_seed=1)
y_pred=model_lr.predict(X_test)

# %%
from sklearn import metrics
print('MSE from bias_variance lib [avg expected loss]: %.3f' % mse)
print('Avg Bias: %.3f' % bias)
print('Avg Variance: %.3f' % var)
print('Mean Square error by Sckit-learn lib: %.3f' % metrics.mean_squared_error(y_test,y_pred))
# Out:
# MSE from bias_variance lib [avg expected loss]: 22.418
# Avg Bias: 20.744
# Avg Variance: 1.674
# Mean Square error by Sckit-learn lib: 23.218

# %% [markdown]
# **Nota:** Sus resultados pueden variar dada la naturaleza estocástica del algoritmo o procedimiento de evaluación, o las diferencias en la precisión numérica. Considere ejecutar el ejemplo varias veces y compare el resultado promedio.
#
# En este caso, podemos ver que el modelo tiene un sesgo alto y una varianza baja. Esto es de esperar dado que estamos utilizando un modelo de regresión lineal. También podemos ver que la suma de la media estimada y la varianza es igual al error estimado del modelo, p. 20.726 + 1.761 = 22.487.

# %% [markdown]
# ### Después de podar — Usando LASSO

# %%
from sklearn.linear_model import LinearRegression, Lasso
lasso_model = Lasso(alpha=0.05)
error_reg_las, bias_reg_las, var_reg_las = bias_variance_decomp(lasso_model, X_train, y_train, X_test, y_test, loss='mse', random_seed=123)
print('MSE from bias_variance lib [avg expected loss]: %.3f' % error_reg_las)
print('Avg Bias: %.3f' % bias_reg_las)
print('Avg Variance: %.3f' % var_reg_las)
print('Mean Square error by Sckit-learn lib: %.3f' % metrics.mean_squared_error(y_test,y_pred))
# Out:
# MSE from bias_variance lib [avg expected loss]: 22.154
# Avg Bias: 20.508
# Avg Variance: 1.646
# Mean Square error by Sckit-learn lib: 23.218

# %% [markdown]
# Se puede observar que el sesgo se ha reducido después de la regularización y hay un ligero aumento en la varianza y el error promedio total también se reduce.

# %% [markdown]
# Aunque lo hemos entendido en la práctica, veamos también una parte matemática.
# Para los modelos de regresión, la descomposición de la varianza del sesgo se puede ver como una función de pérdida al cuadrado básicamente en 3 términos: varianza, sesgo y ruido.
#
# Ignorando el término ruido,
#
# Veamos el valor de Bias & Variance
#
# Función objetivo, $y =f(x)$;
#
# función objetivo predicha, $\hat y=f^(x)=h(x)$;
#
# la pérdida al cuadrado $S=(y−\hat y)^2$;
#
# Expectativa ($E[\hat y]$): esto es sobre conjuntos de entrenamiento.
#
# La predicción principal para la pérdida por error cuadrático es simplemente el promedio de las predicciones ($E[\hat y]$ (la expectativa es sobre los conjuntos de entrenamiento)

# %% [markdown]
# |Metrica| Squared Loss(MSE)| 0-1 Loss|
# |-------|-----------------|--------|
# |Single Loss   |$(y - \hat{y})^2$|$L(y, \hat{y})$|
# |Expected loss  |$E[(y - \hat{y})^2]$ | $E[L(y, \hat{y})]$|
# |Main prediction $E[\hat{y}]$ |media (promedio)| Moda|
# |Bias2         |$ (y-E[{\hat{y}}])^2$| $L(y, E[\hat{y}])$|
# |Variance      | $E[(E[{\hat{y}}] - \hat{y})^2]$ | $E[L(\hat{y}, E[\hat{y}])]$|

# %% [markdown]
# ## Bias, Variance para Clasificación

# %% [markdown]
# Por lo tanto, como resultado de usar el modo para definir la predicción principal de la pérdida 0-1, el sesgo es 1 si la predicción principal no concuerda con la etiqueta verdadera $y$, y 0 en caso contrario:
#
# $$Bias = \begin{cases}
# 1 \text{ if }  y \neq E[{\hat{y}}], \\
# 0 \text{ otherwise}.
# \end{cases}$$
#
# La varianza de la pérdida 0-1 se define como la probabilidad de que la etiqueta predicha no coincida con la predicción principal:
# $$Variance = P(\hat{y} \neq E[\hat{{y}}])$$

# %% [markdown]
# A continuación, echemos un vistazo a lo que sucede con la pérdida si el sesgo es 0. Dada la definición general de pérdida, pérdida = sesgo + varianza, si el sesgo es 0, entonces definimos la pérdida como la varianza:
# $$Loss = 0 + Variance = Loss = P(\hat{y} \neq y) = Variance = P(\hat{y} \neq E[\hat{{y}}])$$
#
# En otras palabras, si un modelo tiene sesgo cero, su pérdida está completamente definida por la varianza, lo cual es intuitivo si pensamos en la varianza en el contexto de un sobreajuste proporcional.
#
# El escenario más sorprendente es si el sesgo es igual a 1. Si el sesgo es igual a 1, el aumento de la varianza puede disminuir la pérdida, lo cual es una observación interesante. Esto se puede ver reescribiendo primero la función de pérdida 0-1 como:
# $$Loss = P(\hat{y} \neq y) = 1 - P(\hat{y} = y)$$

# %% [markdown]
# (Tenga en cuenta que aún no hemos hecho nada nuevo). Ahora, si observamos la ecuación anterior del sesgo, si el sesgo es 1, tenemos $y \neq E[{\hat{y}}]$. Si $y$ no es igual a la predicción principal, pero $y$ también es igual a $\hat y$, entonces $\hat y$ debe ser igual a la predicción principal. Usando el "inverso" ("1 menos"), podemos escribir la pérdida como:
# $$Loss = P(\hat{y} \neq y) = 1 - P(\hat{y} = y) = 1 - P(\hat{y} \neq E[{\hat{y}}])$$
#
# Dado que el sesgo es 1, la pérdida se define como "pérdida = sesgo - varianza" si el sesgo es 1 (o "pérdida = 1 - varianza"). Esto puede parecer bastante poco intuitivo al principio, pero las explicaciones que ofrecen Kong, Dietterich y Domingos fueron que si un modelo tiene un sesgo muy alto, de modo que su predicción principal siempre es incorrecta, aumentar la varianza puede ser beneficioso, ya que aumentar la varianza empujaría el límite de decisión, lo que podría conducir a algunas predicciones correctas solo por casualidad entonces. En otras palabras, para escenarios con alto sesgo, ¡aumentar la varianza puede mejorar (disminuir) la pérdida!

# %%
#Let us consider Iris dataset to calculate the bias vs variance
from sklearn.metrics import zero_one_loss
import pandas as pd
df= pd.read_csv("data/IRIS.csv")
data = df.values
X, y = data[:, :-1], data[:, -1]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=123,
                                                    shuffle=True,
                                                    stratify=y)

# %% [markdown]
# Después de cargar el conjunto de datos, intentemos encontrar el error (pérdida) usando la biblioteca mlxtend y también veremos cómo ciertos modelos (Ej: RandomForest) tienen la capacidad de reducir la varianza.
#
# Primero intentemos con Decision Tree,

# %%
from sklearn.tree import DecisionTreeClassifier
clf_dt = DecisionTreeClassifier(random_state=123)
clf_dt.fit(X_train,y_train)
y_pred=clf_dt.predict(X_test)

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(clf_dt, X_train, y_train, X_test, y_test, 
                                                            loss='0-1_loss',random_seed=123)

print('Average expected loss: %.3f' % avg_expected_loss)
print('Average bias: %.3f' % avg_bias)
print('Average variance: %.3f' % avg_var)
print('Sklearn 0-1 loss: %.3f' % zero_one_loss(y_test,y_pred))
# Out:
# Average expected loss: 0.062
# Average bias: 0.022
# Average variance: 0.040
# Sklearn 0-1 loss: 0.133

# %%
### Después Pruning ###
clf_dt_prnd = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=123)
clf_dt_prnd.fit(X_train,y_train)
y_pred=clf_dt_prnd.predict(X_test)

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        clf_dt_prnd, X_train, y_train, X_test, y_test, 
        loss='0-1_loss',
        random_seed=123)

print('Average expected loss--After pruning: %.3f' % avg_expected_loss)
print('Average bias--After pruning: %.3f' % avg_bias)
print('Average variance--After pruning: %.3f' % avg_var)
print('Sklearn 0-1 loss--After pruning: %.3f' % zero_one_loss(y_test,y_pred))
# Out:
# Average expected loss--After pruning: 0.060
# Average bias--After pruning: 0.022
# Average variance--After pruning: 0.038
# Sklearn 0-1 loss--After pruning: 0.089

# %% [markdown]
# En lo anterior, observamos que la pérdida total esperada = Suma de sesgo + varianza y poda tiene algún efecto sobre la reducción de la varianza.
#
# Hemos escuchado que el modelo Random Forest generalmente ayuda a reducir la varianza (reduce el sobreajuste). Intentemos también ver los resultados del modelo RF.

# %%
from sklearn.ensemble import RandomForestClassifier

clf_RF = RandomForestClassifier(max_depth=2, random_state=0)
clf_RF.fit(X_train,y_train)
y_pred=clf_RF.predict(X_test)

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        clf_RF, X_train, y_train, X_test, y_test, 
        loss='0-1_loss',
        random_seed=123)

print('Average expected loss: %.3f' % avg_expected_loss)
print('Average bias: %.3f' % avg_bias)
print('Average variance: %.3f' % avg_var)
print('Sklearn 0-1 loss: %.3f' % zero_one_loss(y_test,y_pred))
# Out:
# Average expected loss: 0.045
# Average bias: 0.022
# Average variance: 0.023
# Sklearn 0-1 loss: 0.022

# %% [markdown]
# Hay una diferencia significativa en la varianza, se ha reducido drásticamente.
#
# De lo anterior se puede observar que RF en realidad ayuda a reducir la varianza del conjunto de datos.

# %% [markdown]
# Si intentamos ajustar o hiperajustar los parámetros usando `GridSearchCV` o `K-fold`, podríamos terminar reduciendo la varianza mucho más.
#
# De lo anterior, se demuestra claramente que RF ayuda a reducir el sobreajuste o, en otras palabras, ayuda a reducir la varianza del modelo.
#
# ## Modelo KNN
# Intentemos también investigar a KNN
# Por lo general, se sabe que el modelo KNN con valores bajos de k generalmente tiene una varianza alta y un sesgo bajo, pero a medida que aumenta k, la varianza disminuye y el sesgo aumenta.
#
# Tratemos de examinar eso usando el mismo conjunto de datos de Iris.

# %%
from sklearn.metrics import zero_one_loss
from sklearn.neighbors import KNeighborsClassifier
clf_knn = KNeighborsClassifier(n_neighbors=3)
clf_knn.fit(X_train,y_train)
y_pred=clf_knn.predict(X_test)


avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        clf_knn, X_train, y_train, X_test, y_test, 
        loss='0-1_loss',
        random_seed=123)

print('Average expected loss: %.3f' % avg_expected_loss)
print('Average bias: %.3f' % avg_bias)
print('Average variance: %.3f' % avg_var)
print('Sklearn 0-1 loss: %.3f' % zero_one_loss(y_test,y_pred))
# Out:
# Average expected loss: 0.057
# Average bias: 0.044
# Average variance: 0.035
# Sklearn 0-1 loss: 0.044

# %% [markdown]
# Se puede observar que el sesgo es relativamente alto [para k=3] en comparación con la varianza. Y la pérdida esperada es mayor que el modelo RF.
#
# Ahora veamos para varios valores de k cuál es el tren y la gráfica de prueba

# %%
# Visualización de los datos
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
train_score = []
test_score = []
k_vals = []

for k in range(1, 21):
    k_vals.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    
    tr_score = knn.score(X_train, y_train)
    train_score.append(tr_score)
    
    te_score = knn.score(X_test, y_test)
    test_score.append(te_score)
    
plt.figure(figsize=(10,5))
plt.xlabel('Different Values of K')
plt.ylabel('Model score')
plt.plot(k_vals, train_score, color = 'y', label = "training score")
plt.plot(k_vals, test_score, color = 'k', label = 'test score')
plt.legend(bbox_to_anchor=(1, 1),
           bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# Con respecto a este conjunto de datos, podemos observar que para valores bajos de k, la puntuación de la prueba de entrenamiento es mayor y, por otro lado, el conjunto de datos de prueba es bajo, para valores más altos de K, los resultados de la prueba son mejores que el entrenamiento. La compensación de la varianza del sesgo entra en escena al seleccionar el valor k óptimo.
#
# Para varios valores de k en kNN, examinemos también cómo van a ser nuestras pérdidas, sesgos y varianzas.

# %%
bias_KnnClass, var_KnnClass,error_KnnClass, = [], [], []
for k in range(1,21):
    clf_knn = KNeighborsClassifier(n_neighbors=k)
    avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(clf_knn, X_train, y_train, X_test, y_test, loss='0-1_loss', random_seed=123)
    bias_KnnClass.append(avg_bias)
    var_KnnClass.append(avg_var)
    error_KnnClass.append(avg_expected_loss)
    print(f"Average expected loss {avg_expected_loss}")
    print(f"Average bias {avg_bias}")
    print(f"Average variance {avg_var}")
plt.plot(range(1,21), error_KnnClass, 'red', label = 'total_error',linestyle='dashed')
plt.plot(range(1,21), bias_KnnClass, 'brown', label = 'bias^2')
plt.plot(range(1,21), var_KnnClass, 'yellow', label = 'variance')
plt.xlabel('Algorithm Complexity(K)')
plt.ylabel('Error')
plt.legend()
# Out:
# Average expected loss 0.05399999999999999
# Average bias 0.044444444444444446
# Average variance 0.029111111111111112
# Average expected loss 0.05233333333333332
# Average bias 0.044444444444444446
# Average variance 0.03588888888888889
# Average expected loss 0.057111111111111106
# Average bias 0.044444444444444446
# Average variance 0.034666666666666665
# Average expected loss 0.05266666666666666
# Average bias 0.06666666666666667
# Average variance 0.04288888888888889
# Average expected loss 0.05533333333333333
# Average bias 0.044444444444444446
# Average variance 0.033555555555555554
# Average expected loss 0.05144444444444444
# Average bias 0.06666666666666667
# Average variance 0.04366666666666667
# Average expected loss 0.050444444444444445
# Average bias 0.044444444444444446
# Average variance 0.030888888888888893
# Average expected loss 0.04622222222222222
# Average bias 0.022222222222222223
# Average variance 0.04022222222222222
# Average expected loss 0.047444444444444435
# Average bias 0.044444444444444446
# Average variance 0.03166666666666667
# Average expected loss 0.04588888888888889
# Average bias 0.022222222222222223
# Average variance 0.03611111111111111
# Average expected loss 0.047111111111111104
# Average bias 0.044444444444444446
# Average variance 0.03222222222222222
# Average expected loss 0.045888888888888896
# Average bias 0.022222222222222223
# Average variance 0.033
# Average expected loss 0.047666666666666656
# Average bias 0.022222222222222223
# Average variance 0.031
# Average expected loss 0.047333333333333324
# Average bias 0.044444444444444446
# Average variance 0.032
# Average expected loss 0.049333333333333326
# Average bias 0.044444444444444446
# Average variance 0.030888888888888893
# Average expected loss 0.049222222222222216
# Average bias 0.044444444444444446
# Average variance 0.03322222222222222
# Average expected loss 0.050555555555555555
# Average bias 0.022222222222222223
# Average variance 0.03455555555555556
# Average expected loss 0.050333333333333334
# Average bias 0.044444444444444446
# Average variance 0.03411111111111111
# Average expected loss 0.053555555555555544
# Average bias 0.044444444444444446
# Average variance 0.03666666666666667
# Average expected loss 0.054333333333333324
# Average bias 0.044444444444444446
# Average variance 0.036333333333333336

# %% [markdown]
# ## Bias, Variance con TensorFlow

# %%
from mlxtend.evaluate import bias_variance_decomp
from mlxtend.data import boston_housing_data
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import numpy as np

# %%
np.random.seed(1)
tf.random.set_seed(1)


X, y = boston_housing_data()
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=123,
                                                    shuffle=True)


model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation=tf.nn.relu),
    tf.keras.layers.Dense(1)
  ])

optimizer = tf.keras.optimizers.Adam()
model.compile(loss='mean_squared_error', optimizer=optimizer)

model.fit(X_train, y_train, epochs=100, verbose=0)

mean_squared_error(model.predict(X_test), y_test)
# Out:
# 32.69301273447985

# %% [markdown]
# Calculemos la pérdida, el sesgo y la varianza.

# %%
np.random.seed(1)
tf.random.set_seed(1)
 

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        model, X_train, y_train, X_test, y_test, 
        loss='mse',
        num_rounds=100,
        random_seed=123,
        epochs=50,
        verbose=1) 


print('Average expected loss: %.3f' % avg_expected_loss)
print('Average bias: %.3f' % avg_bias)
print('Average variance: %.3f' % avg_var)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 1s 14ms/step - loss: 1167.6215
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 166.3285
# Epoch 3/50
# 12/12 [==============================] - 0s 6ms/step - loss: 88.2287
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 83.4239
# Epoch 5/50
# 12/12 [==============================] - 0s 5ms/step - loss: 72.0455
# Epoch 6/50
# 12/12 [==============================] - 0s 5ms/step - loss: 64.0846
# Epoch 7/50
# 12/12 [==============================] - 0s 6ms/step - loss: 63.0171
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.7429
# Epoch 9/50
# 12/12 [==============================] - 0s 7ms/step - loss: 58.5765
# Epoch 10/50
# 12/12 [==============================] - 0s 6ms/step - loss: 57.4201
# Epoch 11/50
# 12/12 [==============================] - 0s 7ms/step - loss: 54.7284
# Epoch 12/50
# 12/12 [==============================] - 0s 9ms/step - loss: 53.5825
# Epoch 13/50
# 12/12 [==============================] - 0s 7ms/step - loss: 52.0833
# Epoch 14/50
# 12/12 [==============================] - 0s 8ms/step - loss: 51.2204
# Epoch 15/50
# 12/12 [==============================] - 0s 9ms/step - loss: 49.7301
# Epoch 16/50
# 12/12 [==============================] - 0s 9ms/step - loss: 48.5994
# Epoch 17/50
# 12/12 [==============================] - 0s 8ms/step - loss: 50.9882
# Epoch 18/50
# 12/12 [==============================] - 0s 10ms/step - loss: 48.8331
# Epoch 19/50
# 12/12 [==============================] - 0s 10ms/step - loss: 46.3450
# Epoch 20/50
# 12/12 [==============================] - 0s 9ms/step - loss: 45.5498
# Epoch 21/50
# 12/12 [==============================] - 0s 9ms/step - loss: 45.4011
# Epoch 22/50
# 12/12 [==============================] - 0s 8ms/step - loss: 45.1461
# Epoch 23/50
# 12/12 [==============================] - 0s 9ms/step - loss: 48.4895
# Epoch 24/50
# 12/12 [==============================] - 0s 8ms/step - loss: 47.4863
# Epoch 25/50
# 12/12 [==============================] - 0s 11ms/step - loss: 43.1184
# Epoch 26/50
# 12/12 [==============================] - 0s 7ms/step - loss: 42.2655
# Epoch 27/50
# 12/12 [==============================] - 0s 9ms/step - loss: 41.7107
# Epoch 28/50
# 12/12 [==============================] - 0s 5ms/step - loss: 42.3222
# Epoch 29/50
# 12/12 [==============================] - 0s 6ms/step - loss: 41.9292
# Epoch 30/50
# 12/12 [==============================] - 0s 7ms/step - loss: 40.7451
# Epoch 31/50
# 12/12 [==============================] - 0s 6ms/step - loss: 40.4385
# Epoch 32/50
# 12/12 [==============================] - 0s 17ms/step - loss: 40.0837
# Epoch 33/50
# 12/12 [==============================] - 0s 6ms/step - loss: 39.5395
# Epoch 34/50
# 12/12 [==============================] - 0s 6ms/step - loss: 39.3880
# Epoch 35/50
# 12/12 [==============================] - 0s 10ms/step - loss: 39.3062
# Epoch 36/50
# 12/12 [==============================] - 0s 7ms/step - loss: 38.9286
# Epoch 37/50
# 12/12 [==============================] - 0s 9ms/step - loss: 38.8047
# Epoch 38/50
# 12/12 [==============================] - 0s 7ms/step - loss: 38.1208
# Epoch 39/50
# 12/12 [==============================] - 0s 7ms/step - loss: 38.6444
# Epoch 40/50
# 12/12 [==============================] - 0s 5ms/step - loss: 37.6823
# Epoch 41/50
# 12/12 [==============================] - 0s 7ms/step - loss: 37.7795
# Epoch 42/50
# 12/12 [==============================] - 0s 6ms/step - loss: 37.4633
# Epoch 43/50
# 12/12 [==============================] - 0s 5ms/step - loss: 38.0359
# Epoch 44/50
# 12/12 [==============================] - 0s 12ms/step - loss: 36.6456
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 38.0262
# Epoch 46/50
# 12/12 [==============================] - 0s 12ms/step - loss: 36.3878
# Epoch 47/50
# 12/12 [==============================] - 0s 4ms/step - loss: 35.9776
# Epoch 48/50
# 12/12 [==============================] - 0s 6ms/step - loss: 35.9940
# Epoch 49/50
# 12/12 [==============================] - 0s 5ms/step - loss: 35.6951
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 35.5822
# Epoch 1/50
# 12/12 [==============================] - 0s 7ms/step - loss: 3361.9834
# Epoch 2/50
# 12/12 [==============================] - 0s 9ms/step - loss: 1137.6421
# Epoch 3/50
# 12/12 [==============================] - 0s 7ms/step - loss: 276.2766
# Epoch 4/50
# 12/12 [==============================] - 0s 7ms/step - loss: 130.7373
# Epoch 5/50
# 12/12 [==============================] - 0s 9ms/step - loss: 104.8890
# Epoch 6/50
# 12/12 [==============================] - 0s 7ms/step - loss: 87.3688
# Epoch 7/50
# 12/12 [==============================] - 0s 5ms/step - loss: 79.5199
# Epoch 8/50
# 12/12 [==============================] - 0s 7ms/step - loss: 73.9877
# Epoch 9/50
# 12/12 [==============================] - 0s 7ms/step - loss: 70.6304
# Epoch 10/50
# 12/12 [==============================] - 0s 7ms/step - loss: 68.3153
# Epoch 11/50
# 12/12 [==============================] - 0s 9ms/step - loss: 66.8718
# Epoch 12/50
# 12/12 [==============================] - 0s 6ms/step - loss: 64.3328
# Epoch 13/50
# 12/12 [==============================] - 0s 7ms/step - loss: 63.0384
# Epoch 14/50
# 12/12 [==============================] - 0s 7ms/step - loss: 62.3761
# Epoch 15/50
# 12/12 [==============================] - 0s 7ms/step - loss: 60.1777
# Epoch 16/50
# 12/12 [==============================] - 0s 6ms/step - loss: 59.5728
# Epoch 17/50
# 12/12 [==============================] - 0s 7ms/step - loss: 58.4658
# Epoch 18/50
# 12/12 [==============================] - 0s 6ms/step - loss: 58.5205
# Epoch 19/50
# 12/12 [==============================] - 0s 9ms/step - loss: 56.0149
# Epoch 20/50
# 12/12 [==============================] - 0s 9ms/step - loss: 54.7823
# Epoch 21/50
# 12/12 [==============================] - 0s 9ms/step - loss: 54.7764
# Epoch 22/50
# 12/12 [==============================] - 0s 8ms/step - loss: 53.7615
# Epoch 23/50
# 12/12 [==============================] - 0s 6ms/step - loss: 52.9843
# Epoch 24/50
# 12/12 [==============================] - 0s 6ms/step - loss: 52.8334
# Epoch 25/50
# 12/12 [==============================] - 0s 5ms/step - loss: 52.0456
# Epoch 26/50
# 12/12 [==============================] - 0s 7ms/step - loss: 51.5252
# Epoch 27/50
# 12/12 [==============================] - 0s 7ms/step - loss: 50.8834
# Epoch 28/50
# 12/12 [==============================] - 0s 6ms/step - loss: 49.6456
# Epoch 29/50
# 12/12 [==============================] - 0s 7ms/step - loss: 49.2998
# Epoch 30/50
# 12/12 [==============================] - 0s 7ms/step - loss: 48.9695
# Epoch 31/50
# 12/12 [==============================] - 0s 8ms/step - loss: 48.3586
# Epoch 32/50
# 12/12 [==============================] - 0s 6ms/step - loss: 47.8233
# Epoch 33/50
# 12/12 [==============================] - 0s 7ms/step - loss: 48.0871
# Epoch 34/50
# 12/12 [==============================] - 0s 7ms/step - loss: 46.9190
# Epoch 35/50
# 12/12 [==============================] - 0s 5ms/step - loss: 47.3248
# Epoch 36/50
# 12/12 [==============================] - 0s 7ms/step - loss: 46.8324
# Epoch 37/50
# 12/12 [==============================] - 0s 7ms/step - loss: 45.8829
# Epoch 38/50
# 12/12 [==============================] - 0s 6ms/step - loss: 47.4475
# Epoch 39/50
# 12/12 [==============================] - 0s 8ms/step - loss: 47.6348
# Epoch 40/50
# 12/12 [==============================] - 0s 7ms/step - loss: 47.8257
# Epoch 41/50
# 12/12 [==============================] - 0s 10ms/step - loss: 44.6537
# Epoch 42/50
# 12/12 [==============================] - 0s 14ms/step - loss: 44.3874
# Epoch 43/50
# 12/12 [==============================] - 0s 9ms/step - loss: 44.0393
# Epoch 44/50
# 12/12 [==============================] - 0s 11ms/step - loss: 45.4741
# Epoch 45/50
# 12/12 [==============================] - 0s 7ms/step - loss: 45.1097
# Epoch 46/50
# 12/12 [==============================] - 0s 7ms/step - loss: 43.5264
# Epoch 47/50
# 12/12 [==============================] - 0s 7ms/step - loss: 44.3320
# Epoch 48/50
# 12/12 [==============================] - 0s 6ms/step - loss: 43.3184
# Epoch 49/50
# 12/12 [==============================] - 0s 7ms/step - loss: 43.9625
# Epoch 50/50
# 12/12 [==============================] - 0s 6ms/step - loss: 42.8733
# Epoch 1/50
# 12/12 [==============================] - 0s 11ms/step - loss: 8317.9736
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 2336.5422
# Epoch 3/50
# 12/12 [==============================] - 0s 19ms/step - loss: 798.8402
# Epoch 4/50
# 12/12 [==============================] - 0s 12ms/step - loss: 271.9641
# Epoch 5/50
# 12/12 [==============================] - 0s 14ms/step - loss: 157.0854
# Epoch 6/50
# 12/12 [==============================] - 0s 7ms/step - loss: 146.7157
# Epoch 7/50
# 12/12 [==============================] - 0s 6ms/step - loss: 133.2143
# Epoch 8/50
# 12/12 [==============================] - 0s 7ms/step - loss: 123.6325
# Epoch 9/50
# 12/12 [==============================] - 0s 7ms/step - loss: 118.1709
# Epoch 10/50
# 12/12 [==============================] - 0s 7ms/step - loss: 114.1175
# Epoch 11/50
# 12/12 [==============================] - 0s 4ms/step - loss: 110.3683
# Epoch 12/50
# 12/12 [==============================] - 0s 3ms/step - loss: 106.4538
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 99.5194
# Epoch 14/50
# 12/12 [==============================] - 0s 6ms/step - loss: 95.3185
# Epoch 15/50
# 12/12 [==============================] - 0s 4ms/step - loss: 92.3972
# Epoch 16/50
# 12/12 [==============================] - 0s 7ms/step - loss: 90.0207
# Epoch 17/50
# 12/12 [==============================] - 0s 9ms/step - loss: 86.3595
# Epoch 18/50
# 12/12 [==============================] - 0s 6ms/step - loss: 84.4323
# Epoch 19/50
# 12/12 [==============================] - 0s 9ms/step - loss: 81.8972
# Epoch 20/50
# 12/12 [==============================] - 0s 9ms/step - loss: 80.1308
# Epoch 21/50
# 12/12 [==============================] - 0s 7ms/step - loss: 78.4727
# Epoch 22/50
# 12/12 [==============================] - 0s 10ms/step - loss: 76.1226
# Epoch 23/50
# 12/12 [==============================] - 0s 8ms/step - loss: 75.5981
# Epoch 24/50
# 12/12 [==============================] - 0s 9ms/step - loss: 71.7784
# Epoch 25/50
# 12/12 [==============================] - 0s 7ms/step - loss: 70.6731
# Epoch 26/50
# 12/12 [==============================] - 0s 10ms/step - loss: 68.7225
# Epoch 27/50
# 12/12 [==============================] - 0s 5ms/step - loss: 77.1110
# Epoch 28/50
# 12/12 [==============================] - 0s 11ms/step - loss: 66.7506
# Epoch 29/50
# 12/12 [==============================] - 0s 6ms/step - loss: 74.0963
# Epoch 30/50
# 12/12 [==============================] - 0s 7ms/step - loss: 65.1196
# Epoch 31/50
# 12/12 [==============================] - 0s 5ms/step - loss: 62.1501
# Epoch 32/50
# 12/12 [==============================] - 0s 7ms/step - loss: 60.5873
# Epoch 33/50
# 12/12 [==============================] - 0s 6ms/step - loss: 60.1084
# Epoch 34/50
# 12/12 [==============================] - 0s 7ms/step - loss: 58.1687
# Epoch 35/50
# 12/12 [==============================] - 0s 8ms/step - loss: 57.7851
# Epoch 36/50
# 12/12 [==============================] - 0s 7ms/step - loss: 57.1315
# Epoch 37/50
# 12/12 [==============================] - 0s 7ms/step - loss: 55.9469
# Epoch 38/50
# 12/12 [==============================] - 0s 12ms/step - loss: 55.1112
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 54.3573
# Epoch 40/50
# 12/12 [==============================] - 0s 6ms/step - loss: 54.0945
# Epoch 41/50
# 12/12 [==============================] - 0s 7ms/step - loss: 53.3738
# Epoch 42/50
# 12/12 [==============================] - 0s 6ms/step - loss: 52.8603
# Epoch 43/50
# 12/12 [==============================] - 0s 6ms/step - loss: 52.7986
# Epoch 44/50
# 12/12 [==============================] - 0s 5ms/step - loss: 52.8974
# Epoch 45/50
# 12/12 [==============================] - 0s 5ms/step - loss: 52.5672
# Epoch 46/50
# 12/12 [==============================] - 0s 6ms/step - loss: 50.8529
# Epoch 47/50
# 12/12 [==============================] - 0s 6ms/step - loss: 50.2745
# Epoch 48/50
# 12/12 [==============================] - 0s 6ms/step - loss: 49.7993
# Epoch 49/50
# 12/12 [==============================] - 0s 6ms/step - loss: 49.3949
# Epoch 50/50
# 12/12 [==============================] - 0s 7ms/step - loss: 49.0262
# Epoch 1/50
# 12/12 [==============================] - 0s 7ms/step - loss: 7078.5503
# Epoch 2/50
# 12/12 [==============================] - 0s 5ms/step - loss: 2476.2754
# Epoch 3/50
# 12/12 [==============================] - 0s 11ms/step - loss: 600.1674
# Epoch 4/50
# 12/12 [==============================] - 0s 7ms/step - loss: 176.0343
# Epoch 5/50
# 12/12 [==============================] - 0s 7ms/step - loss: 123.4766
# Epoch 6/50
# 12/12 [==============================] - 0s 7ms/step - loss: 107.3822
# Epoch 7/50
# 12/12 [==============================] - 0s 7ms/step - loss: 94.0829
# Epoch 8/50
# 12/12 [==============================] - 0s 6ms/step - loss: 86.7079
# Epoch 9/50
# 12/12 [==============================] - 0s 6ms/step - loss: 82.6734
# Epoch 10/50
# 12/12 [==============================] - 0s 9ms/step - loss: 78.6154
# Epoch 11/50
# 12/12 [==============================] - 0s 7ms/step - loss: 74.3404
# Epoch 12/50
# 12/12 [==============================] - 0s 5ms/step - loss: 70.8965
# Epoch 13/50
# 12/12 [==============================] - 0s 7ms/step - loss: 67.8454
# Epoch 14/50
# 12/12 [==============================] - 0s 6ms/step - loss: 65.4603
# Epoch 15/50
# 12/12 [==============================] - 0s 5ms/step - loss: 65.3493
# Epoch 16/50
# 12/12 [==============================] - 0s 7ms/step - loss: 61.3591
# Epoch 17/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.6799
# Epoch 18/50
# 12/12 [==============================] - 0s 6ms/step - loss: 57.6355
# Epoch 19/50
# 12/12 [==============================] - 0s 6ms/step - loss: 56.1744
# Epoch 20/50
# 12/12 [==============================] - 0s 7ms/step - loss: 55.1607
# Epoch 21/50
# 12/12 [==============================] - 0s 4ms/step - loss: 54.0279
# Epoch 22/50
# 12/12 [==============================] - 0s 4ms/step - loss: 53.5442
# Epoch 23/50
# 12/12 [==============================] - 0s 7ms/step - loss: 52.6572
# Epoch 24/50
# 12/12 [==============================] - 0s 6ms/step - loss: 52.8645
# Epoch 25/50
# 12/12 [==============================] - 0s 6ms/step - loss: 51.7175
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.0158
# Epoch 27/50
# 12/12 [==============================] - 0s 6ms/step - loss: 51.1678
# Epoch 28/50
# 12/12 [==============================] - 0s 4ms/step - loss: 50.6319
# Epoch 29/50
# 12/12 [==============================] - 0s 5ms/step - loss: 50.0969
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 49.8412
# Epoch 31/50
# 12/12 [==============================] - 0s 6ms/step - loss: 49.6663
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 49.0945
# Epoch 33/50
# 12/12 [==============================] - 0s 6ms/step - loss: 48.7141
# Epoch 34/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.9328
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 49.1266
# Epoch 36/50
# 12/12 [==============================] - 0s 6ms/step - loss: 48.3012
# Epoch 37/50
# 12/12 [==============================] - 0s 7ms/step - loss: 48.0523
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.5733
# Epoch 39/50
# 12/12 [==============================] - 0s 6ms/step - loss: 47.5055
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.2541
# Epoch 41/50
# 12/12 [==============================] - 0s 5ms/step - loss: 47.4493
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.4597
# Epoch 43/50
# 12/12 [==============================] - 0s 5ms/step - loss: 47.5948
# Epoch 44/50
# 12/12 [==============================] - 0s 6ms/step - loss: 46.6871
# Epoch 45/50
# 12/12 [==============================] - 0s 7ms/step - loss: 46.6304
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.3210
# Epoch 47/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.7158
# Epoch 48/50
# 12/12 [==============================] - 0s 6ms/step - loss: 46.0533
# Epoch 49/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.0884
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.1273
# Epoch 1/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1065.4998
# Epoch 2/50
# 12/12 [==============================] - 0s 7ms/step - loss: 405.7758
# Epoch 3/50
# 12/12 [==============================] - 0s 7ms/step - loss: 201.7636
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 152.2957
# Epoch 5/50
# 12/12 [==============================] - 0s 5ms/step - loss: 128.1548
# Epoch 6/50
# 12/12 [==============================] - 0s 4ms/step - loss: 131.3345
# Epoch 7/50
# 12/12 [==============================] - 0s 6ms/step - loss: 103.7058
# Epoch 8/50
# 12/12 [==============================] - 0s 6ms/step - loss: 98.3325
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 93.5507
# Epoch 10/50
# 12/12 [==============================] - 0s 7ms/step - loss: 91.3602
# Epoch 11/50
# 12/12 [==============================] - 0s 5ms/step - loss: 89.7364
# Epoch 12/50
# 12/12 [==============================] - 0s 7ms/step - loss: 86.8852
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 85.8065
# Epoch 14/50
# 12/12 [==============================] - 0s 4ms/step - loss: 82.3299
# Epoch 15/50
# 12/12 [==============================] - 0s 6ms/step - loss: 80.7922
# Epoch 16/50
# 12/12 [==============================] - 0s 5ms/step - loss: 80.1918
# Epoch 17/50
# 12/12 [==============================] - 0s 4ms/step - loss: 78.1808
# Epoch 18/50
# 12/12 [==============================] - 0s 6ms/step - loss: 77.0118
# Epoch 19/50
# 12/12 [==============================] - 0s 7ms/step - loss: 80.5672
# Epoch 20/50
# 12/12 [==============================] - 0s 6ms/step - loss: 75.4887
# Epoch 21/50
# 12/12 [==============================] - 0s 5ms/step - loss: 71.6061
# Epoch 22/50
# 12/12 [==============================] - 0s 3ms/step - loss: 70.2235
# Epoch 23/50
# 12/12 [==============================] - 0s 4ms/step - loss: 68.8906
# Epoch 24/50
# 12/12 [==============================] - 0s 4ms/step - loss: 68.5965
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 68.9600
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 66.0005
# Epoch 27/50
# 12/12 [==============================] - 0s 4ms/step - loss: 66.1052
# Epoch 28/50
# 12/12 [==============================] - 0s 3ms/step - loss: 65.2094
# Epoch 29/50
# 12/12 [==============================] - 0s 3ms/step - loss: 67.3345
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 64.5217
# Epoch 31/50
# 12/12 [==============================] - 0s 8ms/step - loss: 62.1251
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.4753
# Epoch 33/50
# 12/12 [==============================] - 0s 8ms/step - loss: 62.3273
# Epoch 34/50
# 12/12 [==============================] - 0s 7ms/step - loss: 59.3079
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 57.2599
# Epoch 36/50
# 12/12 [==============================] - 0s 7ms/step - loss: 56.6677
# Epoch 37/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.4350
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.1800
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.2674
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 53.6881
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.8201
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.9901
# Epoch 43/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.5136
# Epoch 44/50
# 12/12 [==============================] - 0s 3ms/step - loss: 51.7870
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.9179
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.5430
# Epoch 47/50
# 12/12 [==============================] - 0s 3ms/step - loss: 50.1419
# Epoch 48/50
# 12/12 [==============================] - 0s 3ms/step - loss: 48.6884
# Epoch 49/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.6703
# Epoch 50/50
# 12/12 [==============================] - 0s 3ms/step - loss: 47.9135
# Epoch 1/50
# 12/12 [==============================] - 0s 4ms/step - loss: 6651.3608
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1979.6842
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 330.5558
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 143.7624
# Epoch 5/50
# 12/12 [==============================] - 0s 4ms/step - loss: 119.8738
# Epoch 6/50
# 12/12 [==============================] - 0s 3ms/step - loss: 78.0392
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 74.7530
# Epoch 8/50
# 12/12 [==============================] - 0s 3ms/step - loss: 72.2463
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 70.5245
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 69.1318
# Epoch 11/50
# 12/12 [==============================] - 0s 4ms/step - loss: 68.4369
# Epoch 12/50
# 12/12 [==============================] - 0s 7ms/step - loss: 67.2718
# Epoch 13/50
# 12/12 [==============================] - 0s 5ms/step - loss: 66.0677
# Epoch 14/50
# 12/12 [==============================] - 0s 4ms/step - loss: 65.2309
# Epoch 15/50
# 12/12 [==============================] - 0s 7ms/step - loss: 65.6412
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 64.4947
# Epoch 17/50
# 12/12 [==============================] - 0s 4ms/step - loss: 63.5613
# Epoch 18/50
# 12/12 [==============================] - 0s 3ms/step - loss: 63.7804
# Epoch 19/50
# 12/12 [==============================] - 0s 3ms/step - loss: 62.5978
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 62.0273
# Epoch 21/50
# 12/12 [==============================] - 0s 3ms/step - loss: 61.2930
# Epoch 22/50
# 12/12 [==============================] - 0s 4ms/step - loss: 60.7715
# Epoch 23/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.4004
# Epoch 24/50
# 12/12 [==============================] - 0s 4ms/step - loss: 60.5576
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.3356
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.7598
# Epoch 27/50
# 12/12 [==============================] - 0s 5ms/step - loss: 60.4359
# Epoch 28/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.4877
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 57.4620
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.9213
# Epoch 31/50
# 12/12 [==============================] - 0s 3ms/step - loss: 56.9452
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.3196
# Epoch 33/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.6053
# Epoch 34/50
# 12/12 [==============================] - 0s 3ms/step - loss: 55.2693
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 54.7443
# Epoch 36/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.6234
# Epoch 37/50
# 12/12 [==============================] - 0s 7ms/step - loss: 53.8425
# Epoch 38/50
# 12/12 [==============================] - 0s 6ms/step - loss: 53.8192
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 53.3677
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 53.0112
# Epoch 41/50
# 12/12 [==============================] - 0s 3ms/step - loss: 52.5435
# Epoch 42/50
# 12/12 [==============================] - 0s 5ms/step - loss: 52.1434
# Epoch 43/50
# 12/12 [==============================] - 0s 5ms/step - loss: 52.6502
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.4275
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.0043
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 50.7234
# Epoch 47/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.7016
# Epoch 48/50
# 12/12 [==============================] - 0s 8ms/step - loss: 50.3020
# Epoch 49/50
# 12/12 [==============================] - 0s 5ms/step - loss: 50.1554
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 49.5549
# Epoch 1/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1389.7305
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 336.4861
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 217.1946
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 136.7248
# Epoch 5/50
# 12/12 [==============================] - 0s 9ms/step - loss: 109.9197
# Epoch 6/50
# 12/12 [==============================] - 0s 5ms/step - loss: 91.8157
# Epoch 7/50
# 12/12 [==============================] - 0s 5ms/step - loss: 81.3494
# Epoch 8/50
# 12/12 [==============================] - 0s 6ms/step - loss: 75.3067
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 71.4792
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 66.1289
# Epoch 11/50
# 12/12 [==============================] - 0s 3ms/step - loss: 63.1548
# Epoch 12/50
# 12/12 [==============================] - 0s 3ms/step - loss: 61.6508
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.7396
# Epoch 14/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.4815
# Epoch 15/50
# 12/12 [==============================] - 0s 3ms/step - loss: 57.4998
# Epoch 16/50
# 12/12 [==============================] - 0s 3ms/step - loss: 55.9066
# Epoch 17/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.7599
# Epoch 18/50
# 12/12 [==============================] - 0s 4ms/step - loss: 54.7338
# Epoch 19/50
# 12/12 [==============================] - 0s 4ms/step - loss: 53.1811
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.4645
# Epoch 21/50
# 12/12 [==============================] - 0s 3ms/step - loss: 52.4096
# Epoch 22/50
# 12/12 [==============================] - 0s 7ms/step - loss: 51.4461
# Epoch 23/50
# 12/12 [==============================] - 0s 12ms/step - loss: 50.4327
# Epoch 24/50
# 12/12 [==============================] - 0s 4ms/step - loss: 50.5594
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 49.6975
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 50.4329
# Epoch 27/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.1057
# Epoch 28/50
# 12/12 [==============================] - 0s 3ms/step - loss: 47.6195
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.3779
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.5445
# Epoch 31/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.6419
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.6244
# Epoch 33/50
# 12/12 [==============================] - 0s 6ms/step - loss: 45.7278
# Epoch 34/50
# 12/12 [==============================] - 0s 5ms/step - loss: 45.8967
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 44.3804
# Epoch 36/50
# 12/12 [==============================] - 0s 4ms/step - loss: 44.1548
# Epoch 37/50
# 12/12 [==============================] - 0s 5ms/step - loss: 44.3135
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 43.5110
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 45.4356
# Epoch 40/50
# 12/12 [==============================] - 0s 5ms/step - loss: 43.3233
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.8441
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 42.8233
# Epoch 43/50
# 12/12 [==============================] - 0s 8ms/step - loss: 42.5928
# Epoch 44/50
# 12/12 [==============================] - 0s 5ms/step - loss: 41.2552
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 41.5939
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 41.2050
# Epoch 47/50
# 12/12 [==============================] - 0s 4ms/step - loss: 41.1810
# Epoch 48/50
# 12/12 [==============================] - 0s 4ms/step - loss: 40.2441
# Epoch 49/50
# 12/12 [==============================] - 0s 4ms/step - loss: 40.2692
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 40.6196
# Epoch 1/50
# 12/12 [==============================] - 0s 6ms/step - loss: 23971.1016
# Epoch 2/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2336.6450
# Epoch 3/50
# 12/12 [==============================] - 0s 7ms/step - loss: 1434.7777
# Epoch 4/50
# 12/12 [==============================] - 0s 2ms/step - loss: 268.0322
# Epoch 5/50
# 12/12 [==============================] - 0s 3ms/step - loss: 240.7210
# Epoch 6/50
# 12/12 [==============================] - 0s 3ms/step - loss: 97.1384
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 91.6598
# Epoch 8/50
# 12/12 [==============================] - 0s 9ms/step - loss: 77.4036
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 73.9631
# Epoch 10/50
# 12/12 [==============================] - 0s 3ms/step - loss: 70.9851
# Epoch 11/50
# 12/12 [==============================] - 0s 4ms/step - loss: 69.3434
# Epoch 12/50
# 12/12 [==============================] - 0s 6ms/step - loss: 67.1317
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 65.8769
# Epoch 14/50
# 12/12 [==============================] - 0s 4ms/step - loss: 64.7009
# Epoch 15/50
# 12/12 [==============================] - 0s 4ms/step - loss: 63.7201
# Epoch 16/50
# 12/12 [==============================] - 0s 3ms/step - loss: 62.8053
# Epoch 17/50
# 12/12 [==============================] - 0s 10ms/step - loss: 61.8549
# Epoch 18/50
# 12/12 [==============================] - 0s 6ms/step - loss: 61.5462
# Epoch 19/50
# 12/12 [==============================] - 0s 7ms/step - loss: 61.5009
# Epoch 20/50
# 12/12 [==============================] - 0s 8ms/step - loss: 60.8357
# Epoch 21/50
# 12/12 [==============================] - 0s 8ms/step - loss: 59.3866
# Epoch 22/50
# 12/12 [==============================] - 0s 8ms/step - loss: 58.9770
# Epoch 23/50
# 12/12 [==============================] - 0s 7ms/step - loss: 58.1856
# Epoch 24/50
# 12/12 [==============================] - 0s 11ms/step - loss: 58.4170
# Epoch 25/50
# 12/12 [==============================] - 0s 8ms/step - loss: 57.6396
# Epoch 26/50
# 12/12 [==============================] - 0s 6ms/step - loss: 57.7305
# Epoch 27/50
# 12/12 [==============================] - 0s 7ms/step - loss: 56.7115
# Epoch 28/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.2080
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.9465
# Epoch 30/50
# 12/12 [==============================] - 0s 6ms/step - loss: 55.6460
# Epoch 31/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.3663
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.9239
# Epoch 33/50
# 12/12 [==============================] - 0s 4ms/step - loss: 54.8390
# Epoch 34/50
# 12/12 [==============================] - 0s 4ms/step - loss: 54.5114
# Epoch 35/50
# 12/12 [==============================] - 0s 6ms/step - loss: 54.7398
# Epoch 36/50
# 12/12 [==============================] - 0s 4ms/step - loss: 54.2593
# Epoch 37/50
# 12/12 [==============================] - 0s 4ms/step - loss: 53.9782
# Epoch 38/50
# 12/12 [==============================] - 0s 5ms/step - loss: 53.9223
# Epoch 39/50
# 12/12 [==============================] - 0s 5ms/step - loss: 54.4979
# Epoch 40/50
# 12/12 [==============================] - 0s 5ms/step - loss: 54.0058
# Epoch 41/50
# 12/12 [==============================] - 0s 6ms/step - loss: 53.8273
# Epoch 42/50
# 12/12 [==============================] - 0s 7ms/step - loss: 53.2419
# Epoch 43/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.7818
# Epoch 44/50
# 12/12 [==============================] - 0s 7ms/step - loss: 52.1706
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.9818
# Epoch 46/50
# 12/12 [==============================] - 0s 5ms/step - loss: 52.4582
# Epoch 47/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.5900
# Epoch 48/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.4475
# Epoch 49/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.5577
# Epoch 50/50
# 12/12 [==============================] - 0s 6ms/step - loss: 50.9565
# Epoch 1/50
# 12/12 [==============================] - 0s 4ms/step - loss: 28840.8848
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1247.6130
# Epoch 3/50
# 12/12 [==============================] - 0s 7ms/step - loss: 2089.2322
# Epoch 4/50
# 12/12 [==============================] - 0s 8ms/step - loss: 332.7147
# Epoch 5/50
# 12/12 [==============================] - 0s 9ms/step - loss: 229.8848
# Epoch 6/50
# 12/12 [==============================] - 0s 9ms/step - loss: 209.0221
# Epoch 7/50
# 12/12 [==============================] - 0s 6ms/step - loss: 155.9018
# Epoch 8/50
# 12/12 [==============================] - 0s 7ms/step - loss: 143.7935
# Epoch 9/50
# 12/12 [==============================] - 0s 5ms/step - loss: 135.3192
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 127.1120
# Epoch 11/50
# 12/12 [==============================] - 0s 6ms/step - loss: 120.3296
# Epoch 12/50
# 12/12 [==============================] - 0s 6ms/step - loss: 113.8980
# Epoch 13/50
# 12/12 [==============================] - 0s 5ms/step - loss: 108.6042
# Epoch 14/50
# 12/12 [==============================] - 0s 8ms/step - loss: 104.0391
# Epoch 15/50
# 12/12 [==============================] - 0s 5ms/step - loss: 98.6460
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 94.5607
# Epoch 17/50
# 12/12 [==============================] - 0s 7ms/step - loss: 91.8012
# Epoch 18/50
# 12/12 [==============================] - 0s 5ms/step - loss: 88.4134
# Epoch 19/50
# 12/12 [==============================] - 0s 4ms/step - loss: 84.8939
# Epoch 20/50
# 12/12 [==============================] - 0s 7ms/step - loss: 82.3112
# Epoch 21/50
# 12/12 [==============================] - 0s 7ms/step - loss: 80.0586
# Epoch 22/50
# 12/12 [==============================] - 0s 4ms/step - loss: 78.0926
# Epoch 23/50
# 12/12 [==============================] - 0s 4ms/step - loss: 76.6142
# Epoch 24/50
# 12/12 [==============================] - 0s 6ms/step - loss: 74.3759
# Epoch 25/50
# 12/12 [==============================] - 0s 6ms/step - loss: 72.5955
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 71.1769
# Epoch 27/50
# 12/12 [==============================] - 0s 7ms/step - loss: 70.2498
# Epoch 28/50
# 12/12 [==============================] - 0s 9ms/step - loss: 68.6896
# Epoch 29/50
# 12/12 [==============================] - 0s 6ms/step - loss: 67.6454
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 66.4993
# Epoch 31/50
# 12/12 [==============================] - 0s 5ms/step - loss: 65.5570
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 64.5301
# Epoch 33/50
# 12/12 [==============================] - 0s 4ms/step - loss: 63.8849
# Epoch 34/50
# 12/12 [==============================] - 0s 6ms/step - loss: 63.5452
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 62.7691
# Epoch 36/50
# 12/12 [==============================] - 0s 4ms/step - loss: 62.1054
# Epoch 37/50
# 12/12 [==============================] - 0s 6ms/step - loss: 61.6301
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.0220
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 60.6916
# Epoch 40/50
# 12/12 [==============================] - 0s 5ms/step - loss: 60.3700
# Epoch 41/50
# 12/12 [==============================] - 0s 5ms/step - loss: 60.0256
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.4895
# Epoch 43/50
# 12/12 [==============================] - 0s 7ms/step - loss: 59.0378
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.0769
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.6671
# Epoch 46/50
# 12/12 [==============================] - 0s 6ms/step - loss: 58.4254
# Epoch 47/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.7967
# Epoch 48/50
# 12/12 [==============================] - 0s 4ms/step - loss: 57.5386
# Epoch 49/50
# 12/12 [==============================] - 0s 6ms/step - loss: 57.7246
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 57.5853
# Epoch 1/50
# 12/12 [==============================] - 0s 6ms/step - loss: 333.2608
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 125.6521
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 98.4261
# Epoch 4/50
# 12/12 [==============================] - 0s 6ms/step - loss: 75.2438
# Epoch 5/50
# 12/12 [==============================] - 0s 4ms/step - loss: 72.0842
# Epoch 6/50
# 12/12 [==============================] - 0s 4ms/step - loss: 70.1193
# Epoch 7/50
# 12/12 [==============================] - 0s 6ms/step - loss: 67.7482
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 62.7696
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 69.1829
# Epoch 10/50
# 12/12 [==============================] - 0s 6ms/step - loss: 68.4328
# Epoch 11/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.7930
# Epoch 12/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.4850
# Epoch 13/50
# 12/12 [==============================] - 0s 7ms/step - loss: 58.7412
# Epoch 14/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.1441
# Epoch 15/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.1916
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 57.4165
# Epoch 17/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.9474
# Epoch 18/50
# 12/12 [==============================] - 0s 4ms/step - loss: 53.6224
# Epoch 19/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.0157
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.6555
# Epoch 21/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.7051
# Epoch 22/50
# 12/12 [==============================] - 0s 4ms/step - loss: 50.6119
# Epoch 23/50
# 12/12 [==============================] - 0s 4ms/step - loss: 50.3560
# Epoch 24/50
# 12/12 [==============================] - 0s 3ms/step - loss: 48.9163
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.9246
# Epoch 26/50
# 12/12 [==============================] - 0s 3ms/step - loss: 49.6996
# Epoch 27/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.8100
# Epoch 28/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.5567
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.3321
# Epoch 30/50
# 12/12 [==============================] - 0s 3ms/step - loss: 47.5952
# Epoch 31/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.9491
# Epoch 32/50
# 12/12 [==============================] - 0s 3ms/step - loss: 47.0193
# Epoch 33/50
# 12/12 [==============================] - 0s 3ms/step - loss: 47.7194
# Epoch 34/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.2360
# Epoch 35/50
# 12/12 [==============================] - 0s 3ms/step - loss: 44.8602
# Epoch 36/50
# 12/12 [==============================] - 0s 3ms/step - loss: 44.9717
# Epoch 37/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.0166
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 44.3828
# Epoch 39/50
# 12/12 [==============================] - 0s 5ms/step - loss: 44.3617
# Epoch 40/50
# 12/12 [==============================] - 0s 6ms/step - loss: 43.2563
# Epoch 41/50
# 12/12 [==============================] - 0s 6ms/step - loss: 43.5647
# Epoch 42/50
# 12/12 [==============================] - 0s 5ms/step - loss: 46.2267
# Epoch 43/50
# 12/12 [==============================] - 0s 5ms/step - loss: 44.8311
# Epoch 44/50
# 12/12 [==============================] - 0s 6ms/step - loss: 43.0088
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 42.3335
# Epoch 46/50
# 12/12 [==============================] - 0s 5ms/step - loss: 42.2137
# Epoch 47/50
# 12/12 [==============================] - 0s 6ms/step - loss: 42.0055
# Epoch 48/50
# 12/12 [==============================] - 0s 6ms/step - loss: 42.5468
# Epoch 49/50
# 12/12 [==============================] - 0s 3ms/step - loss: 44.9058
# Epoch 50/50
# 12/12 [==============================] - 0s 3ms/step - loss: 41.5452
# Epoch 1/50
# 12/12 [==============================] - 0s 5ms/step - loss: 564.0747
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 311.5079
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 245.9674
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 183.8121
# Epoch 5/50
# 12/12 [==============================] - 0s 4ms/step - loss: 143.0745
# Epoch 6/50
# 12/12 [==============================] - 0s 3ms/step - loss: 120.6817
# Epoch 7/50
# 12/12 [==============================] - 0s 7ms/step - loss: 106.1313
# Epoch 8/50
# 12/12 [==============================] - 0s 3ms/step - loss: 102.7540
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 93.9851
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 89.6266
# Epoch 11/50
# 12/12 [==============================] - 0s 4ms/step - loss: 85.5054
# Epoch 12/50
# 12/12 [==============================] - 0s 4ms/step - loss: 82.7013
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 80.3404
# Epoch 14/50
# 12/12 [==============================] - 0s 4ms/step - loss: 77.8126
# Epoch 15/50
# 12/12 [==============================] - 0s 4ms/step - loss: 81.5092
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 78.2305
# Epoch 17/50
# 12/12 [==============================] - 0s 3ms/step - loss: 78.6772
# Epoch 18/50
# 12/12 [==============================] - 0s 7ms/step - loss: 75.4906
# Epoch 19/50
# 12/12 [==============================] - 0s 9ms/step - loss: 77.8243
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 72.2849
# Epoch 21/50
# 12/12 [==============================] - 0s 6ms/step - loss: 72.9415
# Epoch 22/50
# 12/12 [==============================] - 0s 4ms/step - loss: 71.8290
# Epoch 23/50
# 12/12 [==============================] - 0s 5ms/step - loss: 70.3193
# Epoch 24/50
# 12/12 [==============================] - 0s 8ms/step - loss: 70.9899
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 67.1269
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 73.9310
# Epoch 27/50
# 12/12 [==============================] - 0s 4ms/step - loss: 65.9776
# Epoch 28/50
# 12/12 [==============================] - 0s 4ms/step - loss: 66.5767
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 65.1126
# Epoch 30/50
# 12/12 [==============================] - 0s 3ms/step - loss: 64.4304
# Epoch 31/50
# 12/12 [==============================] - 0s 5ms/step - loss: 63.5225
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 66.2139
# Epoch 33/50
# 12/12 [==============================] - 0s 4ms/step - loss: 66.2396
# Epoch 34/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.8065
# Epoch 35/50
# 12/12 [==============================] - 0s 3ms/step - loss: 61.7233
# Epoch 36/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.3700
# Epoch 37/50
# 12/12 [==============================] - 0s 4ms/step - loss: 60.5455
# Epoch 38/50
# 12/12 [==============================] - 0s 5ms/step - loss: 59.0103
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.9995
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 69.3457
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 57.7479
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 57.5526
# Epoch 43/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.0950
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.1005
# Epoch 45/50
# 12/12 [==============================] - 0s 3ms/step - loss: 58.4889
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.7757
# Epoch 47/50
# 12/12 [==============================] - 0s 3ms/step - loss: 56.0024
# Epoch 48/50
# 12/12 [==============================] - 0s 3ms/step - loss: 58.0132
# Epoch 49/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.3097
# Epoch 50/50
# 12/12 [==============================] - 0s 6ms/step - loss: 60.2368
# Epoch 1/50
# 12/12 [==============================] - 0s 6ms/step - loss: 5137.1885
# Epoch 2/50
# 12/12 [==============================] - 0s 5ms/step - loss: 1775.1396
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 284.7981
# Epoch 4/50
# 12/12 [==============================] - 0s 7ms/step - loss: 225.5426
# Epoch 5/50
# 12/12 [==============================] - 0s 4ms/step - loss: 155.5007
# Epoch 6/50
# 12/12 [==============================] - 0s 4ms/step - loss: 121.8381
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 115.2618
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 109.2311
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 103.4164
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 99.1022
# Epoch 11/50
# 12/12 [==============================] - 0s 4ms/step - loss: 95.0409
# Epoch 12/50
# 12/12 [==============================] - 0s 4ms/step - loss: 91.2155
# Epoch 13/50
# 12/12 [==============================] - 0s 9ms/step - loss: 88.2508
# Epoch 14/50
# 12/12 [==============================] - 0s 5ms/step - loss: 86.6076
# Epoch 15/50
# 12/12 [==============================] - 0s 7ms/step - loss: 82.2948
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 81.5688
# Epoch 17/50
# 12/12 [==============================] - 0s 5ms/step - loss: 77.8636
# Epoch 18/50
# 12/12 [==============================] - 0s 7ms/step - loss: 75.9718
# Epoch 19/50
# 12/12 [==============================] - 0s 5ms/step - loss: 74.4450
# Epoch 20/50
# 12/12 [==============================] - 0s 6ms/step - loss: 72.8311
# Epoch 21/50
# 12/12 [==============================] - 0s 5ms/step - loss: 71.3484
# Epoch 22/50
# 12/12 [==============================] - 0s 13ms/step - loss: 69.7532
# Epoch 23/50
# 12/12 [==============================] - 0s 11ms/step - loss: 68.4866
# Epoch 24/50
# 12/12 [==============================] - 0s 14ms/step - loss: 67.8332
# Epoch 25/50
# 12/12 [==============================] - 0s 9ms/step - loss: 66.6413
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 64.4108
# Epoch 27/50
# 12/12 [==============================] - 0s 6ms/step - loss: 64.1876
# Epoch 28/50
# 12/12 [==============================] - 0s 7ms/step - loss: 62.6518
# Epoch 29/50
# 12/12 [==============================] - 0s 8ms/step - loss: 65.3432
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.6971
# Epoch 31/50
# 12/12 [==============================] - 0s 7ms/step - loss: 60.0839
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.4621
# Epoch 33/50
# 12/12 [==============================] - 0s 5ms/step - loss: 58.9338
# Epoch 34/50
# 12/12 [==============================] - 0s 8ms/step - loss: 57.3186
# Epoch 35/50
# 12/12 [==============================] - 0s 7ms/step - loss: 56.4917
# Epoch 36/50
# 12/12 [==============================] - 0s 7ms/step - loss: 55.8973
# Epoch 37/50
# 12/12 [==============================] - 0s 7ms/step - loss: 55.4463
# Epoch 38/50
# 12/12 [==============================] - 0s 6ms/step - loss: 56.5319
# Epoch 39/50
# 12/12 [==============================] - 0s 6ms/step - loss: 54.3138
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 54.1485
# Epoch 41/50
# 12/12 [==============================] - 0s 6ms/step - loss: 52.9374
# Epoch 42/50
# 12/12 [==============================] - 0s 6ms/step - loss: 52.3357
# Epoch 43/50
# ...
# Epoch 1/50
# 12/12 [==============================] - 0s 4ms/step - loss: 3387.6956
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 573.6047
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 290.3094
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 200.3228
# Epoch 5/50
# 12/12 [==============================] - 0s 4ms/step - loss: 126.3981
# Epoch 6/50
# 12/12 [==============================] - 0s 4ms/step - loss: 100.6891
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 89.9953
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 87.8999
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 83.5012
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 81.4335
# Epoch 11/50
# 12/12 [==============================] - 0s 4ms/step - loss: 80.4086
# Epoch 12/50
# 12/12 [==============================] - 0s 4ms/step - loss: 77.4648
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 75.6533
# Epoch 14/50
# 12/12 [==============================] - 0s 4ms/step - loss: 78.4643
# Epoch 15/50
# 12/12 [==============================] - 0s 3ms/step - loss: 73.2659
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 76.4701
# Epoch 17/50
# 12/12 [==============================] - 0s 4ms/step - loss: 74.1190
# Epoch 18/50
# 12/12 [==============================] - 0s 4ms/step - loss: 74.9705
# Epoch 19/50
# 12/12 [==============================] - 0s 7ms/step - loss: 69.6901
# Epoch 20/50
# 12/12 [==============================] - 0s 9ms/step - loss: 69.6051
# Epoch 21/50
# 12/12 [==============================] - 0s 10ms/step - loss: 68.3504
# 12/12 [==============================] - 0s 3ms/step - loss: 59.5500
# Epoch 27/50
# 12/12 [==============================] - 0s 4ms/step - loss: 65.2173
# Epoch 28/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.8655
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 76.3950
# Epoch 30/50
# 12/12 [==============================] - 0s 3ms/step - loss: 65.8153
# Epoch 31/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.6729
# Epoch 32/50
# 12/12 [==============================] - 0s 3ms/step - loss: 54.9447
# Epoch 33/50
# 12/12 [==============================] - 0s 4ms/step - loss: 53.8754
# Epoch 34/50
# 12/12 [==============================] - 0s 5ms/step - loss: 53.7612
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.6141
# Epoch 36/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.5900
# Epoch 37/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.1039
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.2195
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 50.4606
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 49.1732
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 49.1184
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.9207
# Epoch 43/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.4719
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.8730
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.6767
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.8087
# Epoch 47/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.5511
# Epoch 48/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.6425
# Epoch 49/50
# 12/12 [==============================] - 0s 13ms/step - loss: 49.9719
# Epoch 50/50
# 12/12 [==============================] - 0s 3ms/step - loss: 46.9790
# Epoch 1/50
# 12/12 [==============================] - 0s 7ms/step - loss: 6704.3496
# Epoch 2/50
# 12/12 [==============================] - 0s 5ms/step - loss: 1576.3948
# Epoch 3/50
# 12/12 [==============================] - 0s 3ms/step - loss: 513.3864
# Epoch 4/50
# 12/12 [==============================] - 0s 3ms/step - loss: 323.4183
# Epoch 5/50
# 12/12 [==============================] - 0s 4ms/step - loss: 180.2819
# Epoch 6/50
# 12/12 [==============================] - 0s 4ms/step - loss: 125.0479
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 113.1573
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 101.0624
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 95.8094
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 95.5848
# Epoch 11/50
# 12/12 [==============================] - 0s 4ms/step - loss: 94.0831
# Epoch 12/50
# 12/12 [==============================] - 0s 4ms/step - loss: 87.7241
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 83.9786
# Epoch 14/50
# 12/12 [==============================] - 0s 3ms/step - loss: 83.2558
# Epoch 15/50
# 12/12 [==============================] - 0s 4ms/step - loss: 79.8298
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 78.8426
# Epoch 17/50
# 12/12 [==============================] - 0s 3ms/step - loss: 75.9099
# Epoch 18/50
# 12/12 [==============================] - 0s 3ms/step - loss: 76.5665
# Epoch 19/50
# 12/12 [==============================] - 0s 4ms/step - loss: 72.2073
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 70.1798
# Epoch 21/50
# 12/12 [==============================] - 0s 4ms/step - loss: 68.8503
# Epoch 22/50
# 12/12 [==============================] - 0s 4ms/step - loss: 68.7559
# Epoch 23/50
# 12/12 [==============================] - 0s 4ms/step - loss: 66.2543
# Epoch 24/50
# 12/12 [==============================] - 0s 4ms/step - loss: 65.1616
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 62.9128
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.6808
# Epoch 27/50
# 12/12 [==============================] - 0s 4ms/step - loss: 60.9551
# Epoch 28/50
# 12/12 [==============================] - 0s 3ms/step - loss: 62.0824
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.6183
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 58.5211
# Epoch 31/50
# 12/12 [==============================] - 0s 4ms/step - loss: 57.5385
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.3746
# Epoch 33/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.9977
# Epoch 34/50
# 12/12 [==============================] - 0s 4ms/step - loss: 54.9110
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 55.6740
# Epoch 36/50
# 12/12 [==============================] - 0s 3ms/step - loss: 53.6355
# Epoch 37/50
# 12/12 [==============================] - 0s 3ms/step - loss: 53.1355
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.0928
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.5719
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.7109
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 50.2298
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 49.9873
# Epoch 43/50
# 12/12 [==============================] - 0s 4ms/step - loss: 49.9626
# Epoch 44/50
# 12/12 [==============================] - 0s 5ms/step - loss: 49.3519
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.9064
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.2154
# Epoch 47/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.8024
# Epoch 48/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.9699
# Epoch 49/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.3348
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.1120
# Epoch 1/50
# 12/12 [==============================] - 0s 3ms/step - loss: 1747.6354
# Epoch 2/50
# 12/12 [==============================] - 0s 3ms/step - loss: 664.9246
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 257.4821
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 167.9992
# Epoch 5/50
# 12/12 [==============================] - 0s 4ms/step - loss: 122.3007
# Epoch 6/50
# 12/12 [==============================] - 0s 4ms/step - loss: 102.6399
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 100.6387
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 95.9802
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 95.8038
# Epoch 10/50
# 12/12 [==============================] - 0s 4ms/step - loss: 92.6691
# Epoch 11/50
# 12/12 [==============================] - 0s 4ms/step - loss: 91.5694
# Epoch 12/50
# 12/12 [==============================] - 0s 5ms/step - loss: 91.0820
# Epoch 13/50
# 12/12 [==============================] - 0s 5ms/step - loss: 94.4968
# Epoch 14/50
# 12/12 [==============================] - 0s 9ms/step - loss: 88.6624
# Epoch 15/50
# 12/12 [==============================] - 0s 4ms/step - loss: 87.4774
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 84.9502
# Epoch 17/50
# 12/12 [==============================] - 0s 4ms/step - loss: 84.4224
# Epoch 18/50
# 12/12 [==============================] - 0s 4ms/step - loss: 82.6424
# Epoch 19/50
# 12/12 [==============================] - 0s 4ms/step - loss: 82.8360
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 83.2208
# Epoch 21/50
# 12/12 [==============================] - 0s 5ms/step - loss: 80.3518
# Epoch 22/50
# 12/12 [==============================] - 0s 3ms/step - loss: 78.7872
# Epoch 23/50
# 12/12 [==============================] - 0s 4ms/step - loss: 79.6458
# Epoch 24/50
# 12/12 [==============================] - 0s 3ms/step - loss: 78.1624
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 77.1610
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 74.4435
# Epoch 27/50
# 12/12 [==============================] - 0s 4ms/step - loss: 75.0433
# Epoch 28/50
# 12/12 [==============================] - 0s 4ms/step - loss: 73.6508
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 72.6105
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 72.4534
# Epoch 31/50
# 12/12 [==============================] - 0s 4ms/step - loss: 71.5505
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 70.4263
# Epoch 33/50
# 12/12 [==============================] - 0s 4ms/step - loss: 69.8429
# Epoch 34/50
# 12/12 [==============================] - 0s 4ms/step - loss: 70.2483
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 72.1174
# Epoch 36/50
# 12/12 [==============================] - 0s 4ms/step - loss: 68.5250
# Epoch 37/50
# 12/12 [==============================] - 0s 4ms/step - loss: 68.3295
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 71.9218
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 69.0800
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 67.3462
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 67.4290
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 64.4977
# Epoch 43/50
# 12/12 [==============================] - 0s 4ms/step - loss: 64.6818
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 64.3342
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 64.0606
# Epoch 46/50
# 12/12 [==============================] - 0s 3ms/step - loss: 62.2201
# Epoch 47/50
# 12/12 [==============================] - 0s 3ms/step - loss: 62.2161
# Epoch 48/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.9292
# Epoch 49/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.2117
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.3298
# Epoch 1/50
# 12/12 [==============================] - 0s 3ms/step - loss: 2357.7954
# Epoch 2/50
# 12/12 [==============================] - 0s 3ms/step - loss: 806.1501
# Epoch 3/50
# 12/12 [==============================] - 0s 3ms/step - loss: 371.7664
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 225.6038
# Epoch 5/50
# 12/12 [==============================] - 0s 4ms/step - loss: 179.6190
# Epoch 6/50
# 12/12 [==============================] - 0s 4ms/step - loss: 149.3518
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 135.2071
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 125.4862
# Epoch 9/50
# 12/12 [==============================] - 0s 3ms/step - loss: 113.1499
# Epoch 10/50
# 12/12 [==============================] - 0s 3ms/step - loss: 108.8667
# Epoch 11/50
# 12/12 [==============================] - 0s 3ms/step - loss: 102.0382
# Epoch 12/50
# 12/12 [==============================] - 0s 4ms/step - loss: 96.9763
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 92.1782
# Epoch 14/50
# 12/12 [==============================] - 0s 3ms/step - loss: 87.0325
# Epoch 15/50
# 12/12 [==============================] - 0s 3ms/step - loss: 83.7262
# Epoch 16/50
# 12/12 [==============================] - 0s 4ms/step - loss: 80.4384
# Epoch 17/50
# 12/12 [==============================] - 0s 4ms/step - loss: 80.6387
# Epoch 18/50
# 12/12 [==============================] - 0s 4ms/step - loss: 75.0478
# Epoch 19/50
# 12/12 [==============================] - 0s 4ms/step - loss: 73.6710
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 73.1727
# Epoch 21/50
# 12/12 [==============================] - 0s 4ms/step - loss: 71.3526
# Epoch 22/50
# 12/12 [==============================] - 0s 3ms/step - loss: 67.7926
# Epoch 23/50
# 12/12 [==============================] - 0s 3ms/step - loss: 64.1782
# Epoch 24/50
# 12/12 [==============================] - 0s 4ms/step - loss: 63.5527
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 61.7536
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 59.0801
# Epoch 27/50
# 12/12 [==============================] - 0s 3ms/step - loss: 58.7086
# Epoch 28/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.4920
# Epoch 29/50
# 12/12 [==============================] - 0s 4ms/step - loss: 56.6413
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 53.9340
# Epoch 31/50
# 12/12 [==============================] - 0s 4ms/step - loss: 52.6186
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.8557
# Epoch 33/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.0447
# Epoch 34/50
# 12/12 [==============================] - 0s 4ms/step - loss: 51.2912
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 48.6499
# Epoch 36/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.9106
# Epoch 37/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.2043
# Epoch 38/50
# 12/12 [==============================] - 0s 4ms/step - loss: 46.3846
# Epoch 39/50
# 12/12 [==============================] - 0s 4ms/step - loss: 45.4635
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 45.7589
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 44.8422
# Epoch 42/50
# 12/12 [==============================] - 0s 4ms/step - loss: 44.5749
# Epoch 43/50
# 12/12 [==============================] - 0s 4ms/step - loss: 43.0600
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 47.4067
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 42.5999
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 41.5568
# Epoch 47/50
# 12/12 [==============================] - 0s 10ms/step - loss: 42.1905
# Epoch 48/50
# 12/12 [==============================] - 0s 7ms/step - loss: 41.6856
# Epoch 49/50
# 12/12 [==============================] - 0s 9ms/step - loss: 39.5489
# Epoch 50/50
# 12/12 [==============================] - 0s 4ms/step - loss: 39.0112
# Average expected loss: 51.831
# Average bias: 43.538
# Average variance: 8.294

# %% [markdown]
# Además, definitivamente se recomienda usar la misma cantidad de épocas de entrenamiento que usaría en el conjunto de entrenamiento original para garantizar que se logre la convergencia adecuada.
