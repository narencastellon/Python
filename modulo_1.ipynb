# %% [markdown]
# <a href="https://colab.research.google.com/github/Naren8520/Python/blob/main/modulo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Introducción a Python**

# %%
#@title **Bienvenido al Curso de Machine Learning**
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/Data_analytic.jpg", width=500)

# %% [markdown]
# ## **1.1 Conociendo Python**
#
# Python fue creado a finales de los ochenta por **Guido van Rossum** en el Centro para las Matemáticas y la Informática (CWI, Centrum Wiskunde & Informatica), en los Países Bajos, como un sucesor del lenguaje de programación ABC, capaz de manejar excepciones e interactuar con el sistema operativo Amoeba.
#
# El nombre del lenguaje proviene de la afición de su creador por los humoristas británicos Monty Python.
#
# Python es un lenguaje de programación interpretado, orientado a objetos y de alto nivel con semántica dinámica. Sus estructuras de datos integradas de alto nivel, combinadas con tipado dinámico y enlace dinámico, lo hacen muy atractivo para el desarrollo rápido de aplicaciones, así como para su uso como lenguaje de scripts o pegamento para conectar componentes existentes. La sintaxis simple y fácil de aprender de Python enfatiza la legibilidad y, por lo tanto, reduce el costo de mantenimiento del programa. Python admite módulos y paquetes, lo que fomenta la modularidad del programa y la reutilización del código. El intérprete de Python y la extensa biblioteca estándar están disponibles en formato fuente o binario sin cargo para todas las plataformas principales y se pueden distribuir libremente.
#
# A menudo, los programadores se enamoran de Python debido a la mayor productividad que proporciona. Dado que no hay ningún paso de compilación, el ciclo de edición-prueba-depuración es increíblemente rápido. Depurar los programas de Python es fácil: un error o una entrada incorrecta nunca causarán una falla de segmentación. En cambio, cuando el intérprete descubre un error, genera una excepción. Cuando el programa no detecta la excepción, el intérprete imprime un seguimiento de la pila. Un depurador de nivel de fuente permite la inspección de variables locales y globales, la evaluación de expresiones arbitrarias, el establecimiento de puntos de interrupción, el paso a través del código una línea a la vez, etc. El depurador está escrito en Python, atestiguando el poder introspectivo de Python. Por otro lado, a menudo la forma más rápida de depurar un programa es agregar algunas declaraciones de impresión a la fuente.

# %% [markdown]
# ## **1.2 Trabajando con Colab**
#
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>¿Qué es Colaboratory?</h1>
#
# Colaboratory, también llamado "Colab", te permite ejecutar y programar en Python en tu navegador con las siguientes ventajas:
# - No requiere configuración
# - Da acceso gratuito a GPUs
# - Permite compartir contenido fácilmente
#
# Colab puede facilitar tu trabajo, ya seas <strong>estudiante</strong>, <strong>científico de datos</strong> o <strong>investigador de IA</strong>.

# %% [markdown]
# El documento que están leyendo no es una página web estática, sino un entorno interactivo denominado <strong>cuaderno de Colab</strong> que te permite escribir y ejecutar código.
#
# Los cuadernos de Colab te permiten combinar <strong>código ejecutable</strong> y <strong>texto enriquecido</strong> en un mismo documento, además de <strong>imágenes</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> y mucho más. Los cuadernos que creas en Colab se almacenan en tu cuenta de Google Drive. Puedes compartir tus cuadernos de Colab fácilmente con compañeros de trabajo o amigos, lo que les permite comentarlos o incluso editarlos. Consulta más información en <a href="/notebooks/basic_features_overview.ipynb">Información general sobre Colab</a>. Para crear un cuaderno de Colab, puedes usar el menú Archivo que aparece arriba o bien acceder al enlace para <a href="http://colab.research.google.com#create=true">crear un cuaderno de Colab</a>.
#
# Los cuadernos de Colab son cuadernos de Jupyter alojados en Colab. Para obtener más información sobre el proyecto Jupyter, visita <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# ### **1.2.1 Ciencia de datos**
#
# Con Colab, puedes aprovechar toda la potencia de las bibliotecas más populares de Python para analizar y visualizar datos. La celda de código de abajo utiliza <strong>NumPy</strong> para generar datos aleatorios y <strong>Matplotlib</strong> para visualizarlos. Para editar el código, solo tienes que hacer clic en la celda.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Manipular los datos
import numpy as np
import pandas as pd

# Visualizar nuestro datos de manera gráfica
import matplotlib as plt

# %%
# importa datos
df=pd.read_csv("/content/drive/MyDrive/Curso de ML Peru/data/diamonds.csv")

# %%
categorical_features = ['cut', 'color', 'clarity']
feature = categorical_features[0]
count = df[feature].value_counts()
percent = 100*df[feature].value_counts(normalize=True)
a = pd.DataFrame({'count':count, 'percent':percent.round(1)})
print(a)
count.plot(kind='bar', title=feature);
# Out:
#            count  percent
# Ideal      21551     40.0
# Premium    13791     25.6
# Very Good  12082     22.4
# Good        4906      9.1
# Fair        1610      3.0

# %% [markdown]
# Puedes importar tus propios datos a los cuadernos de Colab desde tu cuenta de Google Drive, incluidas las hojas de cálculo, y también desde GitHub y muchas fuentes más. Para obtener más información sobre cómo importar datos y cómo se puede usar Colab en la ciencia de datos, consulta los enlaces que aparecen en la sección <a href="#working-with-data">Trabajar con datos</a> más abajo.

# %% [markdown]
# ### **1.2.2 Inteligencia Artificial**

# %% [markdown]
# La inteligencia artificial es el campo de estudio mediante el cual una computadora (y sus sistemas) desarrollan la capacidad de realizar con éxito tareas complejas que generalmente requieren inteligencia humana. Estas tareas incluyen, entre otras, percepción visual, reconocimiento de voz, toma de decisiones y traducción entre idiomas. La IA generalmente se define como la ciencia de hacer que las computadoras hagan cosas que requieren inteligencia cuando las realizan humanos.

# %%
#@title **Inteligencia Aritificial**
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/AI.JPG", width=500)

# %% [markdown]
# **Machine Learning**
#
# La idea más sencilla de poder definir el aprendizaje automatico es: "Como la creación de Patrones, algoritmos y modelos Matemáticos Estadísticos en enseñarle a una maquina lo que hacemos nosostros pero de una manera mejor.

# %% [markdown]
# **Tipos de Machine Learning**

# %%
#@title **Tipos de Machine Learning**
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/ML tipos.JPG", width=700)

# %% [markdown]
# Con Colab, puedes importar un conjunto de datos de imágenes, entrenar un clasificador de imágenes con dicho conjunto de datos y evaluar el modelo con tan solo usar unas <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">pocas líneas de código</a>. Los cuadernos de Colab ejecutan código en los servidores en la nube de Google, lo que te permite aprovechar la potencia del hardware de Google, incluidas las <a href="#using-accelerated-hardware">GPU y TPU</a>, independientemente de la potencia de tu equipo. Lo único que necesitas es un navegador.
#
# Colab es una herramienta muy utilizada en la comunidad de aprendizaje automático. Estos son algunos ejemplos de las aplicaciones que tiene Colab:
# - Dar los primeros pasos con TensorFlow
# - Desarrollar y entrenar redes neuronales
# - Experimentar con TPUs
# - Divulgar datos de investigación sobre IA
# - Crear tutoriales
#
# Para ver cuadernos de Colab que demuestran las aplicaciones del aprendizaje automático, consulta los <a href="#machine-learning-examples">ejemplos de aprendizaje automático</a> de abajo.

# %% [markdown]
# **Ingresar ecuación matemática**
#
# *Ingresar ecuación matemática en colab*
#
# * Paso 1
# * Paso2
# * **Paso 3**
# * *Paso 4*
#
# 1. Lista 1
#
#   1.1 . Lista 2

# %% [markdown]
# $$x=\sum_{i=1}^{n} $$

# %% [markdown]
# ### **1.2.3 Subir Imagenes**

# %%
#@title **Bienvenido al Curso de Machine Learning**
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/Supervised Learning vs UnSupervised Learning.JPG", width=3000)

# %% [markdown]
# ### **1.2.4 Subir Video**

# %%
#@title **Subiendo Video** {display-mode: "form"}
# %%html
<b style="font-size:25px">Mi Canal de youtube es Naren Castellon</b>
<hr>
<br>
<iframe width="560" height="315" src="https://www.youtube.com/embed/_s5w0aaZTLY" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <b style="font-size:25px">Mi Canal de youtube es Naren Castellon</b>
# <hr>
# <br>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/_s5w0aaZTLY" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## **1.3 Estructura de datos con Pandas**

# %% [markdown]
# Pandas en Python se ocupa de tres estructuras de datos, a saber
#
# * Serie
# * Marco de datos (DataFrame)
# * Panel

# %% [markdown]
# ### **1.3.1 Dimensiones y descripciones de la estructura de datos de Pandas:**
#
# * **Serie:** matriz homogénea etiquetada 1D, tamaño inmutable
# * **Marcos de datos (DataFrame):** estructura tabular de tamaño mutable etiquetada en 2D con columnas heterogéneas
# * **Panel:** matriz mutable de tamaño etiquetado en 3D.
#
# **Serie en Pandas:**
# La serie es una matriz unidimensional con datos homogéneos. Todos los elementos de la serie deben ser del mismo tipo de datos.
#
# **Características clave de una serie:**
#
# * Datos homogéneos
# * Tamaño inmutable: el tamaño no se puede cambiar
# * Valores de datos mutables

# %% [markdown]
# **DataFrame en pandas:**
# DataFrame es una matriz bidimensional con datos heterogéneos, generalmente representados en formato tabular. Los datos se representan en filas y columnas. Cada columna representa un atributo (características o variable) y cada fila representa a una persona (un registro o un objeto).

# %%
 #@title **Estructura de DataFrame**
 from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/estruct_dataframe.JPG")

# %% [markdown]
# **Características clave de un DataFrame:**
#
# * Datos heterogéneos
# * Tamaño mutable
# * Datos mutables

# %%
# Importar una base dato o conjuntos 
import pandas as pd

# %%
#Permite leer nuestro conjunto de datos
df=pd.read_csv("/content/drive/MyDrive/Curso de ML Peru/data/diamonds.csv")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#Ejemplo de un Dataframe
df.head(20)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %% [markdown]
# **Panel en pandas:**
# El panel es una estructura de datos tridimensional con datos heterogéneos.
#
# Características clave de un panel:
# * Datos heterogéneos
# * Tamaño mutable
# * Datos mutables

# %% [markdown]
# ## **1.4 ESTADÍSTICAS DESCRIPTIVAS O RESUMIDAS EN PYTHON - DESCRIBE ()**
#
# La estadística descriptiva es la técnica matemática que obtiene, organiza, presenta y describe un conjunto de datos con el propósito de facilitar el uso, generalmente con el apoyo de tablas, medidas numéricas o gráficas. Estas técnicas son utilizada en el proceso de investigación, en la etapa donde el investigador necesita procesar y analizar los datos recolectados en dicho estudio.
#
# Se pueden obtener estadísticas descriptivas o resumidas en python - pandas utilizando la función describe - `describe ()`. La función Describe proporciona los valores medio, estándar e IQR.
#
# * Generalmente, la función `describe ()` excluye las columnas de caracteres y proporciona estadísticas resumidas de columnas numéricas.
# * Necesitamos agregar una variable llamada `include = 'all'` para obtener las estadísticas de resumen o estadísticas descriptivas de la columna numérica y de caracteres.

# %%
# Nos devueleve las estadística descriptiva de valores numéricos
df.describe()
# Out:
#               carat         depth  ...             y             z
# count  53940.000000  53940.000000  ...  53940.000000  53940.000000
# mean       0.797940     61.749405  ...      5.734526      3.538734
# std        0.474011      1.432621  ...      1.142135      0.705699
# min        0.200000     43.000000  ...      0.000000      0.000000
# 25%        0.400000     61.000000  ...      4.720000      2.910000
# 50%        0.700000     61.800000  ...      5.710000      3.530000
# 75%        1.040000     62.500000  ...      6.540000      4.040000
# max        5.010000     79.000000  ...     58.900000     31.800000
#
# [8 rows x 7 columns]

# %% [markdown]
# También podemos visualizar la tabla de resumin estadística transponiendola

# %%
df.describe().T
# Out:
#          count         mean          std  ...      50%      75%       max
# carat  53940.0     0.797940     0.474011  ...     0.70     1.04      5.01
# depth  53940.0    61.749405     1.432621  ...    61.80    62.50     79.00
# table  53940.0    57.457184     2.234491  ...    57.00    59.00     95.00
# price  53940.0  3932.799722  3989.439738  ...  2401.00  5324.25  18823.00
# x      53940.0     5.731157     1.121761  ...     5.70     6.54     10.74
# y      53940.0     5.734526     1.142135  ...     5.71     6.54     58.90
# z      53940.0     3.538734     0.705699  ...     3.53     4.04     31.80
#
# [7 rows x 8 columns]

# %%
#Nos devuele las estadística descriptiva de las variable de nuestro conjunto de datos tanto para variables numéricas como variables categoricas
df.describe(include="all")
# Out:
#                carat    cut  color  ...             x             y             z
# count   53940.000000  53940  53940  ...  53940.000000  53940.000000  53940.000000
# unique           NaN      5      7  ...           NaN           NaN           NaN
# top              NaN  Ideal      G  ...           NaN           NaN           NaN
# freq             NaN  21551  11292  ...           NaN           NaN           NaN
# mean        0.797940    NaN    NaN  ...      5.731157      5.734526      3.538734
# std         0.474011    NaN    NaN  ...      1.121761      1.142135      0.705699
# min         0.200000    NaN    NaN  ...      0.000000      0.000000      0.000000
# 25%         0.400000    NaN    NaN  ...      4.710000      4.720000      2.910000
# 50%         0.700000    NaN    NaN  ...      5.700000      5.710000      3.530000
# 75%         1.040000    NaN    NaN  ...      6.540000      6.540000      4.040000
# ...

# %% [markdown]
# ### **1.4.1 Pandas - Estadística descriptiva o resumida de las columnas de caracteres:**
#
# La función  `describe ()` con un argumento llamado include junto con value object, es decir, `include = 'object'` da las estadísticas de resumen de las columnas de caracteres.

# %%
#Resumen estadistica de las columnas caracteres
print(df.describe(include=['object']))# Object -me llama todas variable categoricas
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# ### **1.4.2 ELIMINA LA FILA EN PYTHON PANDAS CON CONDICIONE**
#
# Aprenderemos cómo eliminar o eliminar la fila en python en pandas por índice, eliminar fila por condición en python pandas y eliminar filas por posición. Dejar caer una fila en pandas se logra usando la función .`drop ()` . Veamos un ejemplo de cada uno.
#
# * Elimina Filas con Duplicar en pandas.
# * Elimine o suelte filas con condición en python pandas usando la función `drop ()`.
# * Suelta filas por índice / posición en pandas.
# * Suelta NA filas o filas faltantes en pandas python.

# %% [markdown]
# **Sintaxis de la función `drop ()` en pandas:**
#
# `DataFrame.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors=’raise’)`

# %% [markdown]
# * **labels:**  Cadena o lista de cadenas que hacen referencia a la fila.
# * **axis:**  int o valor de cadena, 0 'índice' para Filas y 1 'columnas' para Columnas.
# * **index o columns:**  etiqueta única o lista. El índice o las columnas son una alternativa al eje y no se pueden usar juntos.
# * **level:** se  utiliza para especificar el nivel, en caso de que el marco de datos tenga un índice de niveles múltiples.
# * **inplace:** realiza  cambios en el marco de datos original si es verdadero.
# * **errores:**  ignora el error si algún valor de la lista no existe y elimina el resto de los valores cuando `errores = 'raise'`
#
# **Creamos el Data Frame**

# %%
import pandas as pd
import numpy as np

#Creamos la series
d = { 'Nombre':['Alisa','raghu','jodha','jodha','raghu','Cathrine', 'Alisa','Bobby','Bobby','Alisa','raghu','Cathrine'],
     'Edad':[26,23,23,23,23,24,26,24,22,26,23,24], 
     'Puntaje':[85,31,55,55,31,77,85,63,42,85,31,np.nan]}
#Create a DataFrame
df = pd.DataFrame(d,columns=['Nombre','Edad','Puntaje'])
df
# Out:
#       Nombre  Edad  Puntaje
# 0      Alisa    26     85.0
# 1      raghu    23     31.0
# 2      jodha    23     55.0
# 3      jodha    23     55.0
# 4      raghu    23     31.0
# 5   Cathrine    24     77.0
# 6      Alisa    26     85.0
# 7      Bobby    24     63.0
# 8      Bobby    22     42.0
# 9      Alisa    26     85.0
# 10     raghu    23     31.0
# 11  Cathrine    24      NaN

# %% [markdown]
# **Simplemente elimine una fila u observación:**
#
# La eliminación de la segunda y tercera fila de un marco de datos se logra de la siguiente manera

# %%
# Elimine una observación o fila

df.drop([1,2])
# Out:
#       Nombre  Edad  Puntaje
# 0      Alisa    26     85.0
# 3      jodha    23     55.0
# 4      raghu    23     31.0
# 5   Cathrine    24     77.0
# 6      Alisa    26     85.0
# 7      Bobby    24     63.0
# 8      Bobby    22     42.0
# 9      Alisa    26     85.0
# 10     raghu    23     31.0
# 11  Cathrine    24      NaN

# %% [markdown]
# El código anterior eliminará la segunda y la tercera fila.
#
# 0: representa la 1ª fila
#
# 1- representa la 2ª fila y así sucesivamente.

# %% [markdown]
# **Suelta una fila u observación por condición:**
#
# podemos eliminar una fila cuando satisfaga una condición específica

# %%
# Elimina una fila por condición

df[df.Nombre != 'Alisa']
# Out:
#       Nombre  Edad  Puntaje
# 1      raghu    23     31.0
# 2      jodha    23     55.0
# 3      jodha    23     55.0
# 4      raghu    23     31.0
# 5   Cathrine    24     77.0
# 7      Bobby    24     63.0
# 8      Bobby    22     42.0
# 10     raghu    23     31.0
# 11  Cathrine    24      NaN

# %%
df[df.Edad !=23]
# Out:
#       Nombre  Edad  Puntaje
# 0      Alisa    26     85.0
# 5   Cathrine    24     77.0
# 6      Alisa    26     85.0
# 7      Bobby    24     63.0
# 8      Bobby    22     42.0
# 9      Alisa    26     85.0
# 11  Cathrine    24      NaN

# %% [markdown]
# El código anterior toma todos los nombres excepto Alisa, por lo que elimina la fila con el nombre 'Alisa'.

# %% [markdown]
# **Suelta una fila u observación por índice:**
#
# Podemos soltar una fila por índice como se muestra a continuación

# %%
#Elimina una fila por índice

df.drop(df.index[2])
# Out:
#       Nombre  Edad  Puntaje
# 0      Alisa    26     85.0
# 1      raghu    23     31.0
# 3      jodha    23     55.0
# 4      raghu    23     31.0
# 5   Cathrine    24     77.0
# 6      Alisa    26     85.0
# 7      Bobby    24     63.0
# 8      Bobby    22     42.0
# 9      Alisa    26     85.0
# 10     raghu    23     31.0
# 11  Cathrine    24      NaN

# %% [markdown]
# El código anterior elimina la fila con el número de índice 2.
#
# **Elimina la fila por posición:**
#
# Ahora dejemos caer las 3 filas inferiores de un marco de datos como se muestra a continuación

# %%
# Drop bottom 3 rows

df[:-3]
# Out:
#      Nombre  Edad  Puntaje
# 0     Alisa    26     85.0
# 1     raghu    23     31.0
# 2     jodha    23     55.0
# 3     jodha    23     55.0
# 4     raghu    23     31.0
# 5  Cathrine    24     77.0
# 6     Alisa    26     85.0
# 7     Bobby    24     63.0
# 8     Bobby    22     42.0

# %% [markdown]
# El código anterior selecciona todas las filas, excepto las 3 filas inferiores, eliminandolas.
#
# **Eliminar filas duplicadas del marco de datos en pandas**

# %%
#@title Filas Duplicadas
from IPython.display import Image
Image("/content/drive/MyDrive/Tutorial de Panda 1/imagenes/drop_duplicate.JPG")

# %% [markdown]
# ahora simplemente eliminamos las filas duplicadas en pandas como se muestra a continuación

# %%
# drop duplicate rows

df.drop_duplicates()
# Out:
#       Nombre  Edad  Puntaje
# 0      Alisa    26     85.0
# 1      raghu    23     31.0
# 2      jodha    23     55.0
# 5   Cathrine    24     77.0
# 7      Bobby    24     63.0
# 8      Bobby    22     42.0
# 11  Cathrine    24      NaN

# %% [markdown]
# En el ejemplo anterior, la primera aparición de la fila duplicada se mantiene y la siguiente aparición duplicada se eliminará.

# %% [markdown]
# **Eliminar filas con valores NA en pandas python**
#
# Elimine las filas incluso con un solo NaN o valores que faltan únicos.

# %%
df.dropna()
# Out:
#       Nombre  Edad  Puntaje
# 0      Alisa    26     85.0
# 1      raghu    23     31.0
# 2      jodha    23     55.0
# 3      jodha    23     55.0
# 4      raghu    23     31.0
# 5   Cathrine    24     77.0
# 6      Alisa    26     85.0
# 7      Bobby    24     63.0
# 8      Bobby    22     42.0
# 9      Alisa    26     85.0
# 10     raghu    23     31.0

# %% [markdown]
# Ahora apliquemolos a nuestro conjunto de datos que estamos usando.
#
# Usaremos la función `drop` para dividir nuestro conjunto de datos en 2 conjuntos, ambas numéricas.

# %%
X=df.drop(["cut","color","clarity"],axis=1)# Eliminamos las variable categoricas
category=df.filter(["cut","color","clarity"])
tabla1=X.drop(["carat","depth","table"],axis=1)
tabla2=X.drop(["x","y","z"],axis=1)

# %%
tabla1.head()
# Out:
#    price     x     y     z
# 0    326  3.95  3.98  2.43
# 1    326  3.89  3.84  2.31
# 2    327  4.05  4.07  2.31
# 3    334  4.20  4.23  2.63
# 4    335  4.34  4.35  2.75

# %%
tabla2.head()
# Out:
#    carat  depth  table  price
# 0   0.23   61.5   55.0    326
# 1   0.21   59.8   61.0    326
# 2   0.23   56.9   65.0    327
# 3   0.29   62.4   58.0    334
# 4   0.31   63.3   58.0    335

# %% [markdown]
# ## **1.5 Unión de DataFrame**

# %% [markdown]
# ### **1.5.1 JOIN EN PANDAS: MERGE DATA FRAMES (INNER, OUTER, RIGHT, LEFT JOIN)**
#
# Podemos unir o fusionar dos marcos de datos en pandas python usando la función `merge()`. Los diferentes argumentos para `merge ()` le permiten realizar una unión natural, unión izquierda, unión derecha y unión externa completa en pandas. También hemos visto otros tipos de operaciones de unión o concatenación como unión basada en índice, índice de fila e índice de columna.
#
# ### Join or Merge in Pandas – Syntax:
# `merge(left_df, right_df, on=’Customer_id’, how=’inner’)`
#
# * **left_df** - Dataframe1
# * **right_df** - Dataframe2.
# * **on :** columnas (nombres) a las que unirse. Debe encontrarse en los objetos DataFrame izquierdo y derecho.
# * **how:** el tipo de combinación debe realizarse: 'izquierda', 'derecha', 'externa', 'interna', el valor predeterminado es la combinación interna
#
# Los marcos de datos deben tener los mismos nombres de columna en los que ocurre la fusión. La función `Merge ()` en pandas es similar a la operación de unión de base de datos en SQL.

# %% [markdown]
# ### **1.5.2 ENTENDIENDO LOS DIFERENTES TIPOS DE JOIN OR MERGE IN PANDAS:**
#
# * **Inner Join or Natural join:** para mantener solo las filas que coinciden con los marcos de datos, especifique el argumento `how=‘inner’.`
# * **Outer Join or Full outer join:** para mantener todas las filas de ambos marcos de datos, especifique `how=‘outer’`.
# * **Left Join or Left outer join:** para incluir todas las filas de su marco de datos xy solo las de y que coinciden, especifique `how=‘left’`.
# * **Right Join or Right outer join:**para incluir todas las filas de su marco de datos y y solo las de x que coinciden, especifique `how=‘right’`.

# %%
#@title **Diferente de Unir DataFrame**
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/logic_set.JPG")

# %% [markdown]
# #### **Pandas de unión interna:**

# %%
#@title **Inner Join**
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/inner_join.JPG")

# %% [markdown]
# Devuelve solo las filas en las que la tabla de la izquierda tiene claves coincidentes en la tabla de la derecha

# %%
inner_join=pd.merge(tabla1,tabla2, on="price",how="inner")

# %%
inner_join.head()
# Out:
#    price     x     y     z  carat  depth  table
# 0    326  3.95  3.98  2.43   0.23   61.5   55.0
# 1    326  3.95  3.98  2.43   0.21   59.8   61.0
# 2    326  3.89  3.84  2.31   0.23   61.5   55.0
# 3    326  3.89  3.84  2.31   0.21   59.8   61.0
# 4    327  4.05  4.07  2.31   0.23   56.9   65.0

# %% [markdown]
# #### **Unión externa en pandas:**

# %%
#@title **Outer Join**
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/outer_join.JPG")

# %% [markdown]
# Devuelve todas las filas de ambas tablas, une los registros de la izquierda que tienen claves coincidentes en la tabla de la derecha. Cuando no haya coincidencias de ninguna tabla, se devolverá NaN

# %%
outer_join=pd.merge(tabla2,tabla1,on="price", how="outer")
outer_join.head()
# Out:
#    carat  depth  table  price     x     y     z
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1   0.23   61.5   55.0    326  3.89  3.84  2.31
# 2   0.21   59.8   61.0    326  3.95  3.98  2.43
# 3   0.21   59.8   61.0    326  3.89  3.84  2.31
# 4   0.23   56.9   65.0    327  4.05  4.07  2.31

# %% [markdown]
# #### **Pandas de unión externa izquierda o unión izquierda:**

# %%
#@title **Left Join**
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/left_join.JPG")

# %% [markdown]
# Devuelve todas las filas de la tabla de la izquierda y todas las filas con claves coincidentes de la tabla de la derecha. Cuando no haya coincidencias de la tabla de la derecha, se devolverá NaN

# %%
left_join=pd.merge(tabla2,tabla1,on="price", how="left")
left_join.head()
# Out:
#    carat  depth  table  price     x     y     z
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1   0.23   61.5   55.0    326  3.89  3.84  2.31
# 2   0.21   59.8   61.0    326  3.95  3.98  2.43
# 3   0.21   59.8   61.0    326  3.89  3.84  2.31
# 4   0.23   56.9   65.0    327  4.05  4.07  2.31

# %% [markdown]
# #### **Pandas de unión externa derecha o unión derecha:**

# %%
#@title **Right Join**
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/right_join.JPG")

# %% [markdown]
# Devuelve todas las filas de la tabla de la derecha y cualquier fila con claves coincidentes de la tabla de la izquierda.

# %%
right_join=pd.merge(tabla2,tabla1,on="price", how="right")
right_join.head()
# Out:
#    carat  depth  table  price     x     y     z
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21   59.8   61.0    326  3.95  3.98  2.43
# 2   0.23   61.5   55.0    326  3.89  3.84  2.31
# 3   0.21   59.8   61.0    326  3.89  3.84  2.31
# 4   0.23   56.9   65.0    327  4.05  4.07  2.31

# %% [markdown]
# ### **COLUMN BIND IN PYTHON PANDAS – CONCATENATE COLUMNS IN PYTHON PANDAS**

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/unir_col.JPG")

# %% [markdown]
# Enlace de columna en pandas python. Aprenderemos cómo concatenar columnas al marco de datos de python pandas usando la función `concat ()` con un ejemplo, es decir, cómo enlazar columnas dos marcos de datos en python pandas.

# %%
tabla2=tabla2.drop(["price"],axis=1)

# %%
tabla2.head()
# Out:
#    carat  depth  table
# 0   0.23   61.5   55.0
# 1   0.21   59.8   61.0
# 2   0.23   56.9   65.0
# 3   0.29   62.4   58.0
# 4   0.31   63.3   58.0

# %%
#concatenar tablas
df=pd.concat([tabla1,tabla2,category],axis=1)
df.head()
# Out:
#    price     x     y     z  carat  depth  table      cut color clarity
# 0    326  3.95  3.98  2.43   0.23   61.5   55.0    Ideal     E     SI2
# 1    326  3.89  3.84  2.31   0.21   59.8   61.0  Premium     E     SI1
# 2    327  4.05  4.07  2.31   0.23   56.9   65.0     Good     E     VS1
# 3    334  4.20  4.23  2.63   0.29   62.4   58.0  Premium     I     VS2
# 4    335  4.34  4.35  2.75   0.31   63.3   58.0     Good     J     SI2

# %% [markdown]
# ## **1.6 APPLY FUNCTIONS IN PYTHON PANDAS – APPLY(), APPLYMAP(), PIPE()**
#
# Para aplicar nuestra propia función o la función de alguna otra biblioteca, los pandas proporcionan tres funciones importantes, a saber, `pipe ()`, `apply ()` y `applymap ()`. Estas funciones se describen a continuación.
#
# * Aplicación de la función de tabla: `pipe ()`
# * Aplicación de la función de fila o columna: `apply()`
# * Aplicación de función inteligente de elementos: `applymap ()`

# %% [markdown]
# ### **1.6.1 Aplicación de la función de tabla: pipe ()**
#
# La función `Pipe ()` realiza la operación personalizada para todo el marco de datos. En el siguiente ejemplo, usaremos la función `pipe ()` para agregar el valor 2 a todo el marco de datos

# %%
import pandas as pd
import numpy as np
import math

# Nuestra función
def adder(adder1,adder2):
   return adder1+adder2

# %%
#Suma 20 a cada elemento de las filas o columnas
print (tabla1.pipe(adder,20))
# Out:
#        price      x      y      z
# 0        346  23.95  23.98  22.43
# 1        346  23.89  23.84  22.31
# 2        347  24.05  24.07  22.31
# 3        354  24.20  24.23  22.63
# 4        355  24.34  24.35  22.75
# ...      ...    ...    ...    ...
# 53935   2777  25.75  25.76  23.50
# 53936   2777  25.69  25.75  23.61
# 53937   2777  25.66  25.68  23.56
# 53938   2777  26.15  26.12  23.74
# 53939   2777  25.83  25.87  23.64
#
# [53940 rows x 4 columns]

# %% [markdown]
# ### **1.6.2 Aplicación de la función de fila o columna: `apply ()`**
#
# La función `apply ()` realiza la operación personalizada para filas o columnas. En el siguiente ejemplo, usaremos la función `apply ()` para encontrar la media de los valores en las filas y la media de los valores en las columnas.

# %%
#calcula la media de cada fila
print (tabla1.apply(np.mean,axis=1))
# Out:
# 0         84.0900
# 1         84.0100
# 2         84.3575
# 3         86.2650
# 4         86.6100
#            ...
# 53935    693.0025
# 53936    693.0125
# 53937    692.9750
# 53938    693.2525
# 53939    693.0850
# Length: 53940, dtype: float64

# %%
#calcula la media de cada columna
tabla1.apply(np.mean,axis=0)
# Out:
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %% [markdown]
# ### **1.6.3 Aplicación de función inteligente de elementos en python pandas: `applymap ()`**
#
# La función `applymap ()` realiza la operación especificada para todos los elementos del marco de datos. utilizaremos el mismo marco de datos para representar un ejemplo de la función `applymap ()`. Multiplicaremos todos los elementos del marco de datos por 2 como se muestra a continuación

# %%
import pandas as pd
import numpy as np
import math

# applymap() Function
tabla1.applymap(lambda x:x*2).head()
# Out:
#    price     x     y     z
# 0    652  7.90  7.96  4.86
# 1    652  7.78  7.68  4.62
# 2    654  8.10  8.14  4.62
# 3    668  8.40  8.46  5.26
# 4    670  8.68  8.70  5.50

# %% [markdown]
# ### **1.6.4 CAMBIAR EL NOMBRE DE LA COLUMNA DE DATAFRAME EN PANDAS PYTHON**
#
# Aprenderemos cómo cambiar el nombre de la columna de dataframe en pandas. Nosotros aprenderemos
#
# * cómo cambiar el nombre de todas las columnas del marco de datos a la vez
# * cómo cambiar el nombre de la columna específica de nuestra elección por nombre de columna.
# * cómo cambiar el nombre de la columna específica de nuestra elección por índice de columna.

# %%
tabla2.columns=["quilate","profundidad","tabla" ]

# %%
tabla2.head()
# Out:
#    quilate  profundidad  tabla
# 0     0.23         61.5   55.0
# 1     0.21         59.8   61.0
# 2     0.23         56.9   65.0
# 3     0.29         62.4   58.0
# 4     0.31         63.3   58.0

# %%
##### cambiando el orden de las filas

tabla1.reindex([8,11,9,2, 1, 0,7,5,6,4,10,3])
# Out:
#     price     x     y     z
# 8     337  3.87  3.78  2.49
# 11    340  3.93  3.90  2.46
# 9     338  4.00  4.05  2.39
# 2     327  4.05  4.07  2.31
# 1     326  3.89  3.84  2.31
# 0     326  3.95  3.98  2.43
# 7     337  4.07  4.11  2.53
# 5     336  3.94  3.96  2.48
# 6     336  3.95  3.98  2.47
# 4     335  4.34  4.35  2.75
# 10    339  4.25  4.28  2.73
# 3     334  4.20  4.23  2.63

# %%
###### Reorganizar filas en orden ascendente pandas python

tabla1.sort_index(axis=0,ascending=True).head()
# Out:
#    price     x     y     z
# 0    326  3.95  3.98  2.43
# 1    326  3.89  3.84  2.31
# 2    327  4.05  4.07  2.31
# 3    334  4.20  4.23  2.63
# 4    335  4.34  4.35  2.75

# %% [markdown]
# ### **1.6.5 ROW BIND EN PYTHON PANDAS ANEXAR O CONCATENAR FILAS EN PYTHON PANDAS**
# Enlazar filas en python pandas: en este tutorial aprenderemos cómo concatenar filas al marco de datos de python pandas con la función `append ()` y la función `concat ()`, es decir, cómo enlazar filas dos marcos de datos en python pandas con un ejemplo.

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/unir_filas.JPG")

# %% [markdown]
# ### Método 1: vincular o concatenar filas de dos marcos de datos en pandas:
#
# Ahora vamos a concatenar o enlazar filas dos marcos de datos df1 y df2.
#
# por lo que el marco de datos enlazado de filas resultante será:

# %%
pd.concat([tabla1,tabla2])
# Out:
#        price     x     y     z  quilate  profundidad  tabla
# 0      326.0  3.95  3.98  2.43      NaN          NaN    NaN
# 1      326.0  3.89  3.84  2.31      NaN          NaN    NaN
# 2      327.0  4.05  4.07  2.31      NaN          NaN    NaN
# 3      334.0  4.20  4.23  2.63      NaN          NaN    NaN
# 4      335.0  4.34  4.35  2.75      NaN          NaN    NaN
# ...      ...   ...   ...   ...      ...          ...    ...
# 53935    NaN   NaN   NaN   NaN     0.72         60.8   57.0
# 53936    NaN   NaN   NaN   NaN     0.72         63.1   55.0
# 53937    NaN   NaN   NaN   NaN     0.70         62.8   60.0
# 53938    NaN   NaN   NaN   NaN     0.86         61.0   58.0
# 53939    NaN   NaN   NaN   NaN     0.75         62.2   55.0
#
# [107880 rows x 7 columns]

# %% [markdown]
# **Método 2: enlazar o concatenar filas de dos marcos de datos en pandas:**
#
# Ahora vamos a concatenar o unir filas de dos marcos de datos tabla1 y tabla2 con el método append
#
# por lo que el marco de datos resultante será:

# %%
tabla1.append(tabla2)
# Out:
#        price     x     y     z  quilate  profundidad  tabla
# 0      326.0  3.95  3.98  2.43      NaN          NaN    NaN
# 1      326.0  3.89  3.84  2.31      NaN          NaN    NaN
# 2      327.0  4.05  4.07  2.31      NaN          NaN    NaN
# 3      334.0  4.20  4.23  2.63      NaN          NaN    NaN
# 4      335.0  4.34  4.35  2.75      NaN          NaN    NaN
# ...      ...   ...   ...   ...      ...          ...    ...
# 53935    NaN   NaN   NaN   NaN     0.72         60.8   57.0
# 53936    NaN   NaN   NaN   NaN     0.72         63.1   55.0
# 53937    NaN   NaN   NaN   NaN     0.70         62.8   60.0
# 53938    NaN   NaN   NaN   NaN     0.86         61.0   58.0
# 53939    NaN   NaN   NaN   NaN     0.75         62.2   55.0
#
# [107880 rows x 7 columns]

# %% [markdown]
# ### **1.6.6 FUNCIÓN COLUMN BIND IN PYTHON PANDAS – CONCATENATE COLUMNS IN PYTHON PANDAS**
#
# Enlace de columna en pandas python. En este tutorial aprenderemos cómo concatenar columnas al marco de datos de python pandas usando la función `concat ()` con un ejemplo, es decir, cómo enlazar columnas dos marcos de datos en python pandas.
#
# La encuadernación de columnas se muestra pictográficamente a continuación
#
# ![](imagenes/unir_col.jpg)

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Curso de ML Peru/imagenes/unir_col.JPG")

# %% [markdown]
# Enlace de columna o concatenación de columnas de dos marcos de datos en python pandas:
# Ahora vamos a concatenar o enlazar columnas dos marcos de datos tabla1 y tabla2. La concatenación de dos marcos de datos se realiza con la función `concat ()` tomando dos marcos de datos como argumento, el `axis= 1` realiza la operación de columna.
#
# El argumento `axis= 1` enlaza los marcos de datos en columna, por lo que el marco de datos enlazado de columna resultante será

# %%
import pandas as pd

pd.concat([tabla1, tabla2], axis=1, ignore_index=True)
# Out:
#           0     1     2     3     4     5     6
# 0       326  3.95  3.98  2.43  0.23  61.5  55.0
# 1       326  3.89  3.84  2.31  0.21  59.8  61.0
# 2       327  4.05  4.07  2.31  0.23  56.9  65.0
# 3       334  4.20  4.23  2.63  0.29  62.4  58.0
# 4       335  4.34  4.35  2.75  0.31  63.3  58.0
# ...     ...   ...   ...   ...   ...   ...   ...
# 53935  2757  5.75  5.76  3.50  0.72  60.8  57.0
# 53936  2757  5.69  5.75  3.61  0.72  63.1  55.0
# 53937  2757  5.66  5.68  3.56  0.70  62.8  60.0
# 53938  2757  6.15  6.12  3.74  0.86  61.0  58.0
# 53939  2757  5.83  5.87  3.64  0.75  62.2  55.0
#
# [53940 rows x 7 columns]

# %% [markdown]
# ## **1.7 FUNCIÓN GROUPBY EN PANDAS - AGRUPA UN MARCO DE DATOS EN PYTHON PANDAS**
#
# La función `groupby()` en pandas python: En este tutorial aprenderemos cómo groupby en python pandas y realizar funciones agregadas. encontraremos la media de un grupo en pandas, la suma de un grupo en pandas python y el recuento de un grupo.
#
# Estaremos trabajando en
#
# * obtener la puntuación media de un grupo usando la función `groupby` en Python
# * obteniendo la suma de la puntuación de un grupo usando la función `groupby` en Python
# * estadísticas descriptivas de un grupo que utiliza pandas la función `groupby`

# %%
import pandas as pd
import numpy as np

b=df["price"].groupby(df["cut"]).mean()
print(b)
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# Una vez agrupado los valores, podemos visualizar en gráfico los valores que hemos agrupado.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
b.plot(kind='bar')
plt.show()

# %%
df.groupby("cut").agg({"price":"describe"})
# Out:
#              price                            ...
#              count         mean          std  ...     50%      75%      max
# cut                                           ...
# Fair        1610.0  4358.757764  3560.386612  ...  3282.0  5205.50  18574.0
# Good        4906.0  3928.864452  3681.589584  ...  3050.5  5028.00  18788.0
# Ideal      21551.0  3457.541970  3808.401172  ...  1810.0  4678.50  18806.0
# Premium    13791.0  4584.257704  4349.204961  ...  3185.0  6296.00  18823.0
# Very Good  12082.0  3981.759891  3935.862161  ...  2648.0  5372.75  18818.0
#
# [5 rows x 8 columns]

# %%
df[['cut',"price"]].groupby(['cut'], as_index = False).mean().sort_values(by = 'price', ascending = False)
# Out:
#          cut        price
# 3    Premium  4584.257704
# 0       Fair  4358.757764
# 4  Very Good  3981.759891
# 1       Good  3928.864452
# 2      Ideal  3457.541970

# %% [markdown]
# ## **1.8 CREAR TABLA DINÁMICA EN PANDAS PYTHON**
#
# Aprenderemos cómo a usar tablas cruzadas en Python pandas (tabla cruzada de 2 vías o tabla cruzada de 3 vías o tabla de contingencia) con un ejemplo. Aprenderemos a crear.
#
# * Tabla cruzada de 2 vías o tabla de contingencia en python pandas
# * Tabla cruzada de 3 vías o tabla de contingencia en python pandas

# %% [markdown]
# ### **1.8.1Tabla cruzada de 2 vías en pandas python:**
# Calcularemos la tabla cruzada de sujeto y resultado como se muestra a continuación
#
# `margins = True` muestra la suma de filas y columnas de la tabla cruzada para que la salida sea

# %%
# 2 manera de cruzar tablas

my_crosstab=pd.crosstab(df.cut, df.color,margins=True)
my_crosstab
# Out:
# color         D     E     F      G     H     I     J    All
# cut
# Fair        163   224   312    314   303   175   119   1610
# Good        662   933   909    871   702   522   307   4906
# Ideal      2834  3903  3826   4884  3115  2093   896  21551
# Premium    1603  2337  2331   2924  2360  1428   808  13791
# Very Good  1513  2400  2164   2299  1824  1204   678  12082
# All        6775  9797  9542  11292  8304  5422  2808  53940

# %%
my_crosstab1=pd.crosstab(df.cut, df.color,margins=True, margins_name='Total Percentage',normalize=True)
my_crosstab1
# Out:
# color                    D         E  ...         J  Total Percentage
# cut                                   ...
# Fair              0.003022  0.004153  ...  0.002206          0.029848
# Good              0.012273  0.017297  ...  0.005692          0.090953
# Ideal             0.052540  0.072358  ...  0.016611          0.399537
# Premium           0.029718  0.043326  ...  0.014980          0.255673
# Very Good         0.028050  0.044494  ...  0.012570          0.223990
# Total Percentage  0.125603  0.181628  ...  0.052058          1.000000
#
# [6 rows x 8 columns]
